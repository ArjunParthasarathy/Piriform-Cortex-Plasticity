# %%
# !pip install numpy
# !pip install scipy
# !pip install torch
# !pip install matplotlib
#!pip install scikit-learn

# %%
import torch
import numpy as np
import scipy
import matplotlib.pyplot as plt

# %%
# Use smaller network for testing - ex 2000 neurons
# Even for the project, doing it for 10^6 neurons would take too long
# Problem this creates: test network is denser than actual network b/c we have 10^3 neurons but 10^2 connections per neuron
num_neurons = 2000
num_i = int(0.1 * num_neurons)
num_e = int(0.9 * num_neurons)

# Num excitatory inputs and inhibitory inputs to each neuron (in reality it should be 500 but we reduce it here to make things faster)
k = 100

# Number of olfactory bulb channels (glomeruli) to each neuron
D = 10 ** 3
# For each neuron, how many glomeruli inputs it receives (should be 10^2)
num_channel_inputs = 100

# Number of odors
P = 16
# Novel activity is up to P // 2, and familiar activity is after
novel_inds = torch.arange(0, P // 2)
familiar_inds = torch.arange(P // 2, P)

# %%
# Creates sparse adjacency matrix with the given probability of edge connection and size mxn
def create_adj_matrix(p, m, n):
    # num_connections = int(p * m * n)
    # m_coords = torch.randint(0, m, (num_connections,))
    # n_coords = torch.randint(0, n, (num_connections,))
    # indices = torch.vstack((m_coords, n_coords))
    # values = torch.ones(num_connections)
    # A_mn = torch.sparse_coo_tensor(indices, values, (m, n))
    probs = torch.ones(m, n) * p
    A_mn = torch.bernoulli(probs)
    return A_mn

# %%
# Draws mitral activity from exponential distribution (by default the rate is 1 / f, so the mean becomes f)
# Otherwise this exponential distribution drops off too quickly
# def compute_mitral_activity(rate=1/f):
#     # Generate new sample for each odor
#     dist = torch.distributions.Exponential(rate).expand(torch.Size([D]))
#     probs = dist.sample(sample_shape=(P,))
#     probs.t_()
#     probs[probs > 1] = 1
#     I = torch.bernoulli(probs) * (i_1 - i_0) + i_0
#     return I

# %%
# Epsilon value defining correlation amount between odors, e < 1, e=0.5
# def correlated_mitral_activity(e):
#     # Covariance matrix representing initial correlations between odors
#     Sigma_0 = torch.ones((P, P)) * e
#     # Each odor has variance 1 (the diagonal represents variances)
#     Sigma_0.fill_diagonal_(1)
#     dist = torch.distributions.MultivariateNormal(torch.zeros(P), Sigma_0)
#     activity = dist.sample(torch.Size([D]))
#     return activity

# %%
# New way of generating correlations between odors: we want different sets of odors to be correlated differently, so that when we subtract each neuron's mean activity over odors, it doesn't cancel out the variation between odors (if all the odors are correlated the same, they will tend to produce similar values for a single neuron and therefore subtracting by the mean will remove these values and only leave small fluctuations)
# So we sample a small set of odors P' and make them linearly independent, and then by multiplying by a P'x P gaussian matrix we project into mitral cell activity space for all P odors, basically making the P odors a linear combination of the set of P' odors (the smaller P' is, the more correlated the resulting set of P odors will be)
# We also scale the variance depending on how small P' is, so we will maintain differently correlated odors, just with higher total correlation if P' is small

# %%
P_prime = 4
def correlated_mitral_activity():
    # Each of the P' odors is independent (correlation of 0)
    sigma_p_prime = torch.zeros((P_prime, P_prime)).fill_diagonal_(1)
    dist = torch.distributions.MultivariateNormal(torch.zeros(P_prime), sigma_p_prime)
    p_prime_activity = dist.sample(torch.Size([D]))
    var = 1 / P_prime
    projection = torch.normal(torch.zeros((P_prime, P)), torch.ones(P_prime, P) * np.sqrt(var))
    activity = p_prime_activity @ projection
    return activity

# %%
# Draws random activity with probability f
def compute_random_mitral_activity():
    I = torch.distributions.Bernoulli(f).sample(torch.Size((D, P))) * (i_1 - i_0) + i_0
    
    return I

# %%
# Takes in mitral activity I and computes feedforward activity h_bar_ff
def compute_feedforward_activity(I):
    # Probability that a channel weight will be nonzero
    p = num_channel_inputs / D
    # Only the first 0.9 * n rows should have this bernoulli number, the rest should be 0 b/c they don't receive a channel input
    # Check whether each neuron still receives ~10^2 nonzero inputs or what the distribution actually looks like
    # Because when we calculate the adjacency matrix we don't go by row (e.g ensuring each neuron has these ~10^2 connections)
    # Alternative: sample from Binomial distribution w/ mean 100
    # The output n for each row is the number of nonzero inputs, and you choose a random subset n of the indices for that row and make them 1
    a = create_adj_matrix(p, num_e, D)
    # Inhibitory neurons don't receive channel input
    # This is the first simplification, where we neglect the first inhibitory layer I_ff
    b = torch.zeros(size=(num_i, D))
    W_ff = torch.cat(tensors=(a, b), dim=0)
    
    h_ff = (W_ff @ I) * (1 / np.sqrt(num_channel_inputs))
    h_bar_ff = h_ff - torch.mean(h_ff, dim=0, keepdim=True)
    return h_bar_ff

# %%
def compute_initial_recurrent_weights():
    k_ee = k_ei = k_ie = k_ii = k
    #p_ee = k_ee / num_e
    # k inhibitory inputs to that e neuron, out of num_i total inhibitory neurons gives the connection probability per neuron
    p_ei = k_ei / num_i
    p_ie = k_ie / num_e
    #p_ii = k_ii / num_i
    
    # Constants
    #w_ee = 0.1
    w_ei = 0.2
    w_ie = 0.5
    #w_ii = 0.3
    # Ignore ee and ii weights for now:
    p_ee = p_ii = w_ee = w_ii = 0
    W_ee = create_adj_matrix(p_ee, num_e, num_e) * w_ee
    W_ei = create_adj_matrix(p_ei, num_e, num_i) * -w_ei
    W_ie = create_adj_matrix(p_ie, num_i, num_e) * w_ie
    W_ii = create_adj_matrix(p_ii, num_i, num_i) * -w_ii
    
    # Concat
    W_1 = torch.cat(tensors=(W_ee, W_ei), dim=1)
    W_2 = torch.cat(tensors=(W_ie, W_ii), dim=1)
    W_rec = torch.cat(tensors=(W_1, W_2), dim=0)
    
    return W_rec

# %%
# Computes activation threshold for neurons, based on the standard deviation of their firing rates across odors
# This average standard deviation, multiplied by theta=2, ensures that each neuron will fire for only 5% of odors
def compute_threshold(total_input, theta):
    # For now, use diff thresholds for each neuron
    center = torch.mean(total_input, dim=1, keepdim=True)
    shift = torch.std(total_input, dim=1, keepdim=True)
    threshold = center + (theta * shift)
    # Since inhibitory neurons are linear
    threshold[num_e:, :] = 0
    return threshold

# %%
# ReLU for excitatory, linear for inhibitory
def neuron_activations(X):
    # Mask to keep excitatory
    mask1 = torch.ones((num_neurons, 1))
    mask1[num_e:, :] = 0
    # Mask to keep inhibitory
    mask2 = torch.zeros((num_neurons, 1))
    mask2[num_e:, :] = 1
    return (torch.relu(X) * mask1) + (X * mask2)

# %%
# Computes R for each odor, with the activation threshold theta
def compute_piriform_response(h_bar_ff, W_rec, threshold_mult):
    # The coefficient of x_bar
    tau = 1
    # time step
    dt = 0.1
    # Number of time steps
    T = 200
    
    # Initial condition where states are gaussian
    mu_0 = 0.
    sigma_0 = 0.2
    X_0 = torch.normal(mu_0, sigma_0, size=(num_neurons, P))
    X = X_0
    
    pts = []
    for i in range(T-2):
        with torch.no_grad():
            part1 = -1 * X
            part2 = (W_rec @ neuron_activations(X)) * (1 / np.sqrt(k))
            part3 = h_bar_ff
            dXdt = (1 / tau) * (part1 + part2 + part3)
            X = X + (dXdt * dt)
        # Look at convergence pattern for first odor, assuming that it'll
        # be similar across odors (since they are all independent)
        #pts.append(torch.mean(dXdt, dim=0)[0].item())
       
       
    # TODO need to track gradient over 2 iterations of recurrent dynamics so we can track the gradient of the E responses back to the previous I responses which are in turn influenced by the prev E responses (thru E to I weights)
    # On the last 2 iterations only, track the gradient
    X.requires_grad_(True)
    for i in range(2):
        
   
    
    
    part1 = -1 * X
    part2 = (W_rec @ neuron_activations(X)) * (1 / np.sqrt(k))
    part3 = h_bar_ff
    with torch.no_grad():
        # The total input to the neuron at this last time step (should be equivalent to the resulting value of X after this time step, since dxdt = 0 after the recurrent network converges)
        total_input = part2 + part3
        threshold = compute_threshold(total_input, threshold_mult)
    
    dXdt = (1 / tau) * (part1 + part2 + part3)
    X = X + (dXdt * dt)
    # Plot derivatives to see if state converged
    # plt.plot(torch.arange(T-1), pts)
    # plt.show()
    R = neuron_activations(X - threshold)
    
    return R

# %%
# Compute dimensionality of activity matrix R for either novel or familiar
def compute_dim(R, odor_inds):
    # Only compute for the excitatory neurons (b/c those are the ones that send signals to rest of brain
    C = torch.cov(R[:num_e, odor_inds[0]:odor_inds[-1]])
    dim = torch.trace(C) ** 2 / torch.trace(C @ C)
    return dim

# trace() is invariant for cyclic permutations of a matrix
# Since C is symmetric, it can be orthogonally diagonalized into UDU^T where U is composed of orthonormal eigenvectors, U^T = U^-1, and D is a diagonal matrix of eigenvalues
# therefore, trace(C) = trace(UDU^T) = trace(DU^TU) = trace(D) = sum(eigvals of C)
# Similarly for the denominator, we need to compute the sum of the squared eigenvalues, which is trace(D^2). trace(D^2) = trace(D^2U^TU) = trace(UD^2U^T) = trace((UDU^T)^2)) [by the property of matrix exponentiation for a diagonalizable matrix] = trace(C^2) = trace(C @ C)

# %%
# Dimensionalities should be similar before performing plasticity, upper bound on dimensionality is 8 b/c there are 8 odors each for novel/familiar (this is the rank of the cov matrix)
# Measures how many orthogonal directions in neuron space are needed to explain the set of odors (the max number of orthogonal directions is the number of neurons themselves)
# print(C_novel0)
# print(C_familiar0)

# %%
# Loop over odors and after computing R_alpha (stationary/convergence state) for each odor, perform weight update on W_rec
# Compute increment for W_rec(i,j) which is only dependent on R_alpha(i) and R_alpha(j) (two different neurons in W_rec)
# Do it only for the nonzero weights for now (because these are the only active connections between neurons)
# - Later, we could explore whether new synapses etc are created/destroyed (the changing of a weight from zero to nonzero)

# %%
# Set up MLP which takes in R_alpha(i) and R_alpha(j) and computes an output value delta_W_rec(i,j) which is the update value for W_rec(i,j)
# Single MLP for each class of weights (W_ee, W_ei, etc), and we adjust the weights of this MLP
# - Because plasticity is different between different kinds of neurons

# %%
# Start w/ small MLP - 1 hidden layer (ex. 20 units), 2 inputs, 1 output
# Each time step, we want to compute the weight update
# Compute the responses using the existing weight matrix, run thru the MLP to get the weight update, and update the weight matrix
# After n iterations, we want to calculate dimensionality (from the covariance matrix we generate from the neuron responses)
# Loss function: dim Novel / dim Familiar
# - Potential case: might make dim(Novel) as 0

# Might have to regularize the firing rate - should be close to a value we set
# Ex. could take average of neuron responses at beginning (before plasticity) and set that as target firing rate

# To prevent exploding/vanishing gradients, might have to truncate the gradient (stop it from updating after a certain iteration) because when we accumulate the gradient over the time steps to compute the response, it might blow up or just vanish
# - since the weight update is used to update the weight matrix and compute the next time step of neuron response, which in turn is fed into the MLP to compute the next weight update (very cyclical)
# Another solution - only backprop thru the last time steps of the recurrent dynamics (the time steps to compute a neuron response), b/c these are where the neuron response converges to the actual value
# Lookup how to truncate gradient PyTorch

# Instead of having plasticity act on all weights, only have plasticity between certain cell types (ex. between E and E, it will create positive feedback loop on weight update and may cause gradient blowup)
# For now, only use MLP for E -> I (minimize likelihood of gradient blowup), don't have to truncate gradient yet

# %%
import torch.nn as nn
import torch.optim as optim

def create_model() -> torch.nn.Sequential:
    # Number of neurons in hidden layer
    hidden_size = 100
    # Constrain output to certain values: nn.Hardtanh(-1, 1)
    model = nn.Sequential(
        nn.Linear(2, hidden_size),
        nn.ReLU(),
        nn.Linear(hidden_size, 1),
    )
    
    return model

# %%
# Start and stop indices for the section of W_rec we want to update, respectively 
# Takes in R_alpha, a vector of neuron responses to a particular odor
def compute_update(model: torch.nn.Sequential, R_alpha: torch.Tensor, update_inds) -> torch.Tensor:
    # Compute the same pairs of R_i and R_j for every odor
    # 1D vectors of the pre and postsynaptic neurons corresponding to the nonzero weights of W_rec
    postsyn_responses = R_alpha[update_inds[0]]
    presyn_responses = R_alpha[update_inds[1]]
    model_input = torch.vstack((presyn_responses, postsyn_responses)).t()
    slice_updates = model(model_input)
    
    updates = slice_updates.squeeze(dim=1)
    
    return updates

# %%
# TODO rerun E->I to see if gradient propagates differently
def odor_corrs(R):
    # We don't care about the actual responses per odor, just about a neuron's fluctuations around its mean response across odors
    R_adjusted = R[:num_e] - torch.mean(R[:num_e], dim=1, keepdim=True)
    # Each odor becomes a variable, because we want to calculate correlations between them across neurons
    R_adjusted.t_()
    # Like cov but divides by standard deviations, effectively normalizing the values (the diagonals of the resulting matrix become 1)
    sigma_E = torch.corrcoef(R_adjusted)
    # We only care about the correlations between the familiar odors
    familiar_corrs = sigma_E[P//2:P, P//2:P] - torch.eye(P // 2)
    corr_sum = torch.sum(familiar_corrs ** 2)
    avg_corr = torch.mean(torch.abs(familiar_corrs))
    
    return corr_sum, avg_corr

# %%
# Sparsity per odor, across all (E) neurons
def sparsity_per_odor(R):
    # If we have zero responses
    sp_per_odor = 1 - ((torch.sum(R[:num_e], dim=0) ** 2) / (num_e * (torch.sum(R[:num_e] ** 2, dim=0))))
    # Sparsity nan means that the responses were all 0 for an odor, meaning that its max sparsity of 1
    sp_per_odor = torch.nan_to_num(sp_per_odor, nan=1.0)
    return sp_per_odor

# Sparsity per (E) neuron, across a given odor family
def sparsity_per_neuron(R, odor_inds):
    sp_per_neuron = 1 - (
                (torch.sum(R[:num_e, odor_inds], dim=1) ** 2) / (P * torch.sum(R[:num_e, odor_inds] ** 2, dim=1)))
    return sp_per_neuron

# %%
# Try to minimize the correlations between values
def loss_fn(R, lambda_corr, lambda_mu, lambda_var, lambda_sp):
    corr_sum, avg_corr = odor_corrs(R)
    corr_loss = (1 / P) * corr_sum
    corr_term = lambda_corr * corr_loss
    
    means = torch.mean(R[:num_e], dim=0)
    means_novel = torch.mean(means[novel_inds])
    means_familiar = torch.mean(means[familiar_inds])
    mu_term = lambda_mu * (((means_familiar - means_novel) / (means_novel + means_familiar)) ** 2)
    mu_term = torch.nan_to_num(mu_term, nan=0.)
    
    vars = torch.var(R[:num_e], dim=0)
    var_novel = torch.mean(vars[novel_inds])
    var_familiar = torch.mean(vars[familiar_inds])
    var_term = lambda_var * (((var_familiar - var_novel) / (var_novel + var_familiar)) ** 2)
    var_term = torch.nan_to_num(var_term, nan=0.)
    
    sparsities = sparsity_per_odor(R)
    spars_novel = torch.mean(sparsities[novel_inds])
    spars_familiar = torch.mean(sparsities[familiar_inds])
    # All sparsities are 0, so this regularization term is at its highest value
    if (spars_novel + spars_familiar) < 1e-6:
        # Sparsities are technically the same so the term shouldn't contribute to loss
        spars_term = 0
    else:
        spars_term = lambda_sp * (((spars_familiar - spars_novel) / (spars_novel + spars_familiar)) ** 2)
    
    print("Avg Corr: %.4f, Corr: %.4f, Mu: %.4f, Var: %.4f, Sparsity: %.4f" % (avg_corr, corr_term, mu_term, var_term, spars_term))
    loss = corr_term + mu_term + var_term + spars_term
    return loss

# %%
# Detaching vs zero grad - should detach because we have a term dependent on the previous model iteration which isn't zero but some constant gradient, accumulated from that model output

# %%
# Upper bound for weight matrix (most weights become 10x-15x initial value if they take the naive approach of increasing inhibition)
mult = 100
w_ie = 0.5
max_weight = mult * w_ie

def loss_after_odors(model: torch.nn.Sequential, W_rec: torch.Tensor, R_current: torch.Tensor, h_bar_ff: torch.Tensor, threshold_mult, plasticity_rate, weight_decay_rate, update_inds, lambda_corr, lambda_mu, lambda_var, lambda_sp, detach_grad=True, with_loss=False):
   # First, compute the respective weight updates through the novel and familiar odors from the current neural responses (which are from the current weight matrix)
    
    #updates = W_rec[update_inds].detach().clone()
    #updates.requires_grad_(True)
    updates = torch.zeros_like(W_rec[update_inds], requires_grad=True)
    W_rec.requires_grad_(True)
   
    # Remove shuffle for now
    for i in range(P):
        ou = compute_update(model, R_current[:, i], update_inds)
        odor_update = ou
        # At the very end, we accumulate into W_rec so we need to check whether the new W_rec value at the very end will fit within max_weight
        with torch.no_grad():
            val_tensor = ((1 - plasticity_rate * weight_decay_rate) * W_rec[update_inds]) + updates + (plasticity_rate * odor_update)
            # E->I weights are only positive
            condition = torch.logical_and(torch.gt(val_tensor, 0.), torch.le(val_tensor, max_weight))
        
        normed_update = torch.where(condition, odor_update, 0.)
        updates = updates + normed_update
    
    updates = plasticity_rate * (updates - weight_decay_rate * W_rec[update_inds])
    
    W_rec = torch.index_put(W_rec, update_inds, updates, accumulate=True)
    
    R = compute_piriform_response(h_bar_ff, W_rec, threshold_mult)
    R_new = R
    
    if detach_grad:
        # We want a new R response tensor which only has the previous weight update but not anything before that
        W_rec = W_rec.detach()
        R_new = compute_piriform_response(h_bar_ff, W_rec, threshold_mult)

    
    if with_loss:
        loss = loss_fn(R, lambda_corr, lambda_mu, lambda_var, lambda_sp)
    else:
        loss = 0
    
    return loss, W_rec, R_new

# %%
# def loss_per_odor(W_rec: torch.Tensor, R_current: torch.Tensor, h_bar_ff: torch.Tensor):
#     W_rec.requires_grad_(True)
#     
#     W_rec = weight_update(W_rec, R_current, (num_e, num_neurons), (0, num_e))
#     
#     # Then find the updated neural responses from the updated weight matrix
#     R_new = compute_piriform_response(h_bar_ff, W_rec, theta)
#     
#     # Then, compute the loss, which is the ratio of the novel and familiar dimensionalities
#     loss = loss_fn(R_new)
#    
#     # We want a new R response tensor which only has the previous weight update but not anything before that
#     W_static = W_rec.detach().clone()
#     R_tosend = compute_piriform_response(h_bar_ff, W_static, theta)
#    
#     
#     return loss, W_rec, R_tosend

# %%
# This MLP changes in every loop iteration, its not biologically plausible
# We also need an outer loop to mimic multiple animals each doing this set of sniffs, then we get a more generalizable MLP which can take in two responses and compute what the ideal update would be
# A validation run would be where we freeze the weights of the MLP, give it a random initial weight matrix and h_bar feedforward input, and across loop iterations have it reduce the correlations between odors

# # Number of independent "sniffs" of the 16 odors
# num_epochs = 1000
# # Number of standard deviations from mean, 2 will make 5% of the neurons fire for a given odor
# theta = 2
# 
# model = create_model()
# # Rate at which we update W w/ delta W
# plasticity_rate = 1e-3
# #optimizer = optim.SGD(model.parameters(), lr=1e-3, momentum=0.9)
# optimizer = optim.Adam(model.parameters(), lr=1e-3)
# 
# i = correlated_mitral_activity(e=0.8)
# hbar_ff = compute_feedforward_activity(i)
# # print(f"Initial feedforward dim (novel): {compute_dim(hbar_ff, novel_inds)}")
# # print(f"Initial feedforward dim (novel): {compute_dim(hbar_ff, familiar_inds)}")
# # Initial W_rec
# W = compute_initial_recurrent_weights()
# W.requires_grad_(True)
# 
# with torch.no_grad():
#     post = (num_e, num_neurons)
#     pre = (0, num_e)
#     weights_slice = W[post[0]:post[1], pre[0]:pre[1]]
#     inds = torch.nonzero(weights_slice, as_tuple=True)
#     update_inds = (inds[0] + post[0], inds[1] + pre[0])
# 
# torch.autograd.set_detect_anomaly(True)
# # Initial neuron responses
# R = compute_piriform_response(hbar_ff, W, theta)
# with torch.no_grad():
# #     C_novel0 = compute_dim(R, novel_inds)
# #     C_familiar0 = compute_dim(R, familiar_inds)
# #     print(f"Initial responses dim (novel): {C_novel0}")
# #     print(f"Initial responses dim (familiar): {C_familiar0}")
#     print("Initial loss: \t", end="")
#     loss_fn(R)
# 
# for _ in range(num_epochs):
#     # Approach 1: update weights thru each iteration of odors then at very end compute gradient
#     optimizer.zero_grad()
#     loss, W, R = loss_after_odors(model, W, R, hbar_ff, theta, plasticity_rate, update_inds, with_loss=True)
#     loss.backward()
#     optimizer.step()

# %%
# To check theoretical minimum odor correlations, generate random gaussian matrix of shape (num_neurons, 8) and this is what the minimum correlation should be
# mu = torch.zeros((num_neurons, 16))
# std = torch.ones((num_neurons, 16))
# R_random = torch.normal(mu, std)
# loss_min = loss_fn(R_random)
# Theoretical min of 0.05

# %%
def verify_initial_activities():
    runs = 100
    avg_corrs = torch.empty((runs,))
    total_losses = torch.empty((runs,))
    for i in range(runs):
        with torch.no_grad():
            a = correlated_mitral_activity()
            h = compute_feedforward_activity(a)
            w = compute_initial_recurrent_weights()
            r = compute_piriform_response(h, w, 0)
        R_adjusted = r - torch.mean(r, dim=1, keepdim=True)
        R_adjusted.t_()
        sigma_E = torch.corrcoef(R_adjusted)
        familiar_corrs = sigma_E[P//2:P, P//2:P] - torch.eye(P // 2)
        total_loss = torch.sum(familiar_corrs ** 2)
        avg_corr = torch.mean(torch.abs(familiar_corrs))
        print(f"Loss: {total_loss.item()}, Avg Corr: {avg_corr}")
        total_losses[i] = total_loss
        avg_corrs[i] = avg_corr
    plt.hist(avg_corrs, bins=15)

# %%
# Number of independent "sniffs" of the 16 odors
n_inner = 50
# Number of different realizations of the odor sniffing process
n_outer = 100

plasticity_rate = 1e-1

# Number of inner epochs between model updates (right now we perform one update after all the inner epochs), n_update <= n_inner
n_update = 10
# Number of inner epochs across which the gradient is tracked (right now we detach the gradient after each inner epoch), n_track <= n_inner
n_track = n_update

# n_track = n_update to test formulation where we track the gradient across a subset of the inner epochs and update the model
# If n_update > n_track, the model will have multiple "gradient" paths of loss accumulated: ex. inner epochs 1-5 and a separate branch of 6-10
# If n_update < n_track, it doesn't matter b/c the model will truncate the history past its previous update since the gradient is zeroed

# Number of standard deviations from mean, we are trying 0 b/c 1 and 2 is too sparse
threshold_multiplier = 0

weight_decay = 1
# How much to weight each of the regularization terms
# Increasing sparsity term to 10 makes it still decorrelate, 100 is too much and doesn't improve sparsity
lambda_corr, lambda_mu, lambda_var, lambda_sp = 1, 0, 0, 0

# TODO reconsider regularization

# Try lowering plasticity across iterations
# start_rate = 1e-3
# end_rate = 1e-5
# # scale = np.log10(end_rate / start_rate)
# def plasticity_ramp(i):
#     # Linear ramp
#     slope = (end_rate - start_rate) / n_outer
#     rate = (slope * i) + start_rate
#     # Exponential ramp
#     #rate = start_rate * (10 ** ((scale * i) / epochs_outer))
#     return rate

model = create_model()

def train_model():
    
    # Model LR doesn't improve decorrelation much
    optimizer = optim.SGD(model.parameters(), lr=1e-3, momentum=0.9)
    #optimizer = optim.Adam(model.parameters(), lr=1e-5)
    
    post = (num_e, num_neurons)
    pre = (0, num_e)
    
    updates_per_outer = n_inner // n_update
    num_losses = int(updates_per_outer * n_outer)
    losses = torch.empty(size=(num_losses,))
    # batch every 20 (ex. tried 50 and was slightly more noisy (but w/ similar mean))
    #batch_every = 20
    #batch_loss = 0
    for outer_e in range(n_outer):
        i = correlated_mitral_activity()
        hbar_ff = compute_feedforward_activity(i)
        # print(f"Initial feedforward dim (novel): {compute_dim(hbar_ff, novel_inds)}")
        # print(f"Initial feedforward dim (novel): {compute_dim(hbar_ff, familiar_inds)}")
        # Initial W_rec
        
        W_initial = compute_initial_recurrent_weights()
        W = W_initial.clone()
        W.requires_grad_(True)
        
        with torch.no_grad():
            weights_slice = W[post[0]:post[1], pre[0]:pre[1]]
            inds = torch.nonzero(weights_slice, as_tuple=True)
            update_inds = (inds[0] + post[0], inds[1] + pre[0])
        
        # Initial neuron responses
        R = compute_piriform_response(hbar_ff, W, threshold_multiplier)
        #plasticity_rate = plasticity_ramp(outer_e)
        
        for i in range(1, n_inner + 1):
            with_loss = False
            detach_grad = False
            if i % n_update == 0:
                with_loss = True
                print(f"Outer epoch {outer_e}, Inner epoch {i}, Loss: \t", end="")
            if i % n_track == 0:
                detach_grad = True
            loss, W, R = loss_after_odors(model, W, R, hbar_ff, threshold_multiplier, plasticity_rate, weight_decay, update_inds, lambda_corr, lambda_mu, lambda_var, lambda_sp, detach_grad=detach_grad, with_loss=with_loss)
            
            if with_loss:
                final_loss = loss
                # Don't include loss-min term
                R_initial = compute_piriform_response(hbar_ff, W_initial, threshold_multiplier)
                initial_loss = loss_fn(R_initial, lambda_corr, lambda_mu, lambda_var, lambda_sp)
                total_loss = final_loss / initial_loss
                print(f"Loss ratio: {total_loss}")
                losses[(outer_e * updates_per_outer)  + (i // n_update) - 1] = total_loss
                total_loss.backward()   
                optimizer.step()
                optimizer.zero_grad()
        
        # if outer_e % batch_every == 0:
        #     batch_loss.backward()   
        #     optimizer.step()
        #     optimizer.zero_grad()
        #     batch_loss = 0
                
    return losses

# %%
# Now that regime works, can we optimize it w/ hyperparameters as much as possible
# Also try "batching" across outer epochs - keep gradient over multiple outer epochs
# Then add concept of inner epochs, and then eventually move on to loss regularization terms
# Generate plot of odor correlations over time, say which hyperparameters made it work (and which update rule)
# - move into separate notebook to show the stages of the code

# %%
losses = train_model()
# Out:
# Outer epoch 0, Inner epoch 10, Loss: 	Avg Corr: 0.3099, Corr: 0.5947, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3044, Corr: 0.5716, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0403791666030884
# Outer epoch 0, Inner epoch 20, Loss: 	Avg Corr: 0.3110, Corr: 0.5945, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3044, Corr: 0.5716, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0400618314743042
# Outer epoch 0, Inner epoch 30, Loss: 	Avg Corr: 0.3109, Corr: 0.5934, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3044, Corr: 0.5716, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.03819739818573
# Outer epoch 0, Inner epoch 40, Loss: 	Avg Corr: 0.3108, Corr: 0.5932, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3044, Corr: 0.5716, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0378270149230957
# Outer epoch 0, Inner epoch 50, Loss: 	Avg Corr: 0.3108, Corr: 0.5931, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3044, Corr: 0.5716, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0376325845718384
# Outer epoch 1, Inner epoch 10, Loss: 	Avg Corr: 0.2829, Corr: 0.5268, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2644, Corr: 0.4867, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0823708772659302
# Outer epoch 1, Inner epoch 20, Loss: 	Avg Corr: 0.2803, Corr: 0.5167, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2644, Corr: 0.4867, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0617178678512573
# Outer epoch 1, Inner epoch 30, Loss: 	Avg Corr: 0.2772, Corr: 0.5103, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2644, Corr: 0.4867, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0483990907669067
# Outer epoch 1, Inner epoch 40, Loss: 	Avg Corr: 0.2767, Corr: 0.5091, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2644, Corr: 0.4867, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0460644960403442
# Outer epoch 1, Inner epoch 50, Loss: 	Avg Corr: 0.2765, Corr: 0.5085, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2644, Corr: 0.4867, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0448545217514038
# Outer epoch 2, Inner epoch 10, Loss: 	Avg Corr: 0.3593, Corr: 0.8255, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3682, Corr: 0.8249, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.000772476196289
# Outer epoch 2, Inner epoch 20, Loss: 	Avg Corr: 0.3569, Corr: 0.8204, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3682, Corr: 0.8249, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9945414662361145
# Outer epoch 2, Inner epoch 30, Loss: 	Avg Corr: 0.3580, Corr: 0.8241, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3682, Corr: 0.8249, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9990506172180176
# Outer epoch 2, Inner epoch 40, Loss: 	Avg Corr: 0.3580, Corr: 0.8245, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3682, Corr: 0.8249, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9995616674423218
# Outer epoch 2, Inner epoch 50, Loss: 	Avg Corr: 0.3580, Corr: 0.8243, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3682, Corr: 0.8249, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9993628263473511
# Outer epoch 3, Inner epoch 10, Loss: 	Avg Corr: 0.2783, Corr: 0.5234, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2686, Corr: 0.4847, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0798720121383667
# Outer epoch 3, Inner epoch 20, Loss: 	Avg Corr: 0.2771, Corr: 0.5255, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2686, Corr: 0.4847, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0843383073806763
# Outer epoch 3, Inner epoch 30, Loss: 	Avg Corr: 0.2770, Corr: 0.5245, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2686, Corr: 0.4847, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0821003913879395
# Outer epoch 3, Inner epoch 40, Loss: 	Avg Corr: 0.2767, Corr: 0.5240, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2686, Corr: 0.4847, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0811045169830322
# Outer epoch 3, Inner epoch 50, Loss: 	Avg Corr: 0.2771, Corr: 0.5243, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2686, Corr: 0.4847, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0818692445755005
# Outer epoch 4, Inner epoch 10, Loss: 	Avg Corr: 0.3008, Corr: 0.6174, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3028, Corr: 0.5997, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0294936895370483
# Outer epoch 4, Inner epoch 20, Loss: 	Avg Corr: 0.2984, Corr: 0.6091, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3028, Corr: 0.5997, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0156002044677734
# Outer epoch 4, Inner epoch 30, Loss: 	Avg Corr: 0.2979, Corr: 0.6058, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3028, Corr: 0.5997, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.010043740272522
# Outer epoch 4, Inner epoch 40, Loss: 	Avg Corr: 0.2978, Corr: 0.6052, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3028, Corr: 0.5997, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0090864896774292
# Outer epoch 4, Inner epoch 50, Loss: 	Avg Corr: 0.2977, Corr: 0.6052, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3028, Corr: 0.5997, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.009064793586731
# Outer epoch 5, Inner epoch 10, Loss: 	Avg Corr: 0.2842, Corr: 0.5754, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2778, Corr: 0.5174, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.1121678352355957
# Outer epoch 5, Inner epoch 20, Loss: 	Avg Corr: 0.2883, Corr: 0.5982, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2778, Corr: 0.5174, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.15619695186615
# Outer epoch 5, Inner epoch 30, Loss: 	Avg Corr: 0.2856, Corr: 0.5857, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2778, Corr: 0.5174, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.1321613788604736
# Outer epoch 5, Inner epoch 40, Loss: 	Avg Corr: 0.2855, Corr: 0.5855, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2778, Corr: 0.5174, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.131653904914856
# Outer epoch 5, Inner epoch 50, Loss: 	Avg Corr: 0.2852, Corr: 0.5844, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2778, Corr: 0.5174, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.1295205354690552
# Outer epoch 6, Inner epoch 10, Loss: 	Avg Corr: 0.3084, Corr: 0.5868, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3190, Corr: 0.6379, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.920009434223175
# Outer epoch 6, Inner epoch 20, Loss: 	Avg Corr: 0.3043, Corr: 0.5707, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3190, Corr: 0.6379, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8947867751121521
# Outer epoch 6, Inner epoch 30, Loss: 	Avg Corr: 0.3046, Corr: 0.5709, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3190, Corr: 0.6379, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8950211405754089
# Outer epoch 6, Inner epoch 40, Loss: 	Avg Corr: 0.3047, Corr: 0.5708, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3190, Corr: 0.6379, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8949480652809143
# Outer epoch 6, Inner epoch 50, Loss: 	Avg Corr: 0.3046, Corr: 0.5708, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3190, Corr: 0.6379, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8948147892951965
# Outer epoch 7, Inner epoch 10, Loss: 	Avg Corr: 0.4124, Corr: 0.9409, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.4047, Corr: 0.9077, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.036616563796997
# Outer epoch 7, Inner epoch 20, Loss: 	Avg Corr: 0.4125, Corr: 0.9435, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.4047, Corr: 0.9077, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0395243167877197
# Outer epoch 7, Inner epoch 30, Loss: 	Avg Corr: 0.4128, Corr: 0.9432, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.4047, Corr: 0.9077, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0391499996185303
# Outer epoch 7, Inner epoch 40, Loss: 	Avg Corr: 0.4126, Corr: 0.9422, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.4047, Corr: 0.9077, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0380584001541138
# Outer epoch 7, Inner epoch 50, Loss: 	Avg Corr: 0.4124, Corr: 0.9417, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.4047, Corr: 0.9077, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0374454259872437
# Outer epoch 8, Inner epoch 10, Loss: 	Avg Corr: 0.2789, Corr: 0.5214, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2917, Corr: 0.5465, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9539642333984375
# Outer epoch 8, Inner epoch 20, Loss: 	Avg Corr: 0.2769, Corr: 0.5177, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2917, Corr: 0.5465, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.947276771068573
# Outer epoch 8, Inner epoch 30, Loss: 	Avg Corr: 0.2764, Corr: 0.5171, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2917, Corr: 0.5465, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9460925459861755
# Outer epoch 8, Inner epoch 40, Loss: 	Avg Corr: 0.2762, Corr: 0.5168, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2917, Corr: 0.5465, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9455937147140503
# Outer epoch 8, Inner epoch 50, Loss: 	Avg Corr: 0.2762, Corr: 0.5167, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2917, Corr: 0.5465, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9454972147941589
# Outer epoch 9, Inner epoch 10, Loss: 	Avg Corr: 0.3363, Corr: 0.6937, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3284, Corr: 0.6567, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0562267303466797
# Outer epoch 9, Inner epoch 20, Loss: 	Avg Corr: 0.3373, Corr: 0.6987, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3284, Corr: 0.6567, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.063834309577942
# Outer epoch 9, Inner epoch 30, Loss: 	Avg Corr: 0.3371, Corr: 0.6974, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3284, Corr: 0.6567, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0618999004364014
# Outer epoch 9, Inner epoch 40, Loss: 	Avg Corr: 0.3372, Corr: 0.6974, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3284, Corr: 0.6567, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0619838237762451
# Outer epoch 9, Inner epoch 50, Loss: 	Avg Corr: 0.3370, Corr: 0.6967, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3284, Corr: 0.6567, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.060856580734253
# Outer epoch 10, Inner epoch 10, Loss: 	Avg Corr: 0.2736, Corr: 0.4393, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2835, Corr: 0.4789, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.917280912399292
# Outer epoch 10, Inner epoch 20, Loss: 	Avg Corr: 0.2641, Corr: 0.4063, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2835, Corr: 0.4789, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8483529686927795
# Outer epoch 10, Inner epoch 30, Loss: 	Avg Corr: 0.2667, Corr: 0.4138, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2835, Corr: 0.4789, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8640295267105103
# Outer epoch 10, Inner epoch 40, Loss: 	Avg Corr: 0.2664, Corr: 0.4128, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2835, Corr: 0.4789, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.86201012134552
# Outer epoch 10, Inner epoch 50, Loss: 	Avg Corr: 0.2666, Corr: 0.4135, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2835, Corr: 0.4789, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8633659482002258
# Outer epoch 11, Inner epoch 10, Loss: 	Avg Corr: 0.2973, Corr: 0.5556, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3035, Corr: 0.5754, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9656311273574829
# Outer epoch 11, Inner epoch 20, Loss: 	Avg Corr: 0.2917, Corr: 0.5380, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3035, Corr: 0.5754, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9350779056549072
# Outer epoch 11, Inner epoch 30, Loss: 	Avg Corr: 0.2915, Corr: 0.5373, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3035, Corr: 0.5754, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9337629079818726
# Outer epoch 11, Inner epoch 40, Loss: 	Avg Corr: 0.2915, Corr: 0.5372, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3035, Corr: 0.5754, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9336725473403931
# Outer epoch 11, Inner epoch 50, Loss: 	Avg Corr: 0.2915, Corr: 0.5372, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3035, Corr: 0.5754, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9335261583328247
# Outer epoch 12, Inner epoch 10, Loss: 	Avg Corr: 0.2472, Corr: 0.4722, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2620, Corr: 0.4952, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9535332918167114
# Outer epoch 12, Inner epoch 20, Loss: 	Avg Corr: 0.2514, Corr: 0.4875, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2620, Corr: 0.4952, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9845033288002014
# Outer epoch 12, Inner epoch 30, Loss: 	Avg Corr: 0.2509, Corr: 0.4880, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2620, Corr: 0.4952, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.98543781042099
# Outer epoch 12, Inner epoch 40, Loss: 	Avg Corr: 0.2510, Corr: 0.4882, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2620, Corr: 0.4952, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9858752489089966
# Outer epoch 12, Inner epoch 50, Loss: 	Avg Corr: 0.2510, Corr: 0.4882, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2620, Corr: 0.4952, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9858822226524353
# Outer epoch 13, Inner epoch 10, Loss: 	Avg Corr: 0.2749, Corr: 0.5103, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2946, Corr: 0.5646, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9038617014884949
# Outer epoch 13, Inner epoch 20, Loss: 	Avg Corr: 0.2703, Corr: 0.4984, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2946, Corr: 0.5646, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8827017545700073
# Outer epoch 13, Inner epoch 30, Loss: 	Avg Corr: 0.2710, Corr: 0.4995, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2946, Corr: 0.5646, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8846278786659241
# Outer epoch 13, Inner epoch 40, Loss: 	Avg Corr: 0.2710, Corr: 0.4996, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2946, Corr: 0.5646, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8847890496253967
# Outer epoch 13, Inner epoch 50, Loss: 	Avg Corr: 0.2710, Corr: 0.4995, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2946, Corr: 0.5646, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8846709132194519
# Outer epoch 14, Inner epoch 10, Loss: 	Avg Corr: 0.3049, Corr: 0.5864, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3161, Corr: 0.6110, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9596894383430481
# Outer epoch 14, Inner epoch 20, Loss: 	Avg Corr: 0.2997, Corr: 0.5704, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3161, Corr: 0.6110, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.93361896276474
# Outer epoch 14, Inner epoch 30, Loss: 	Avg Corr: 0.2998, Corr: 0.5700, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3161, Corr: 0.6110, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9329559803009033
# Outer epoch 14, Inner epoch 40, Loss: 	Avg Corr: 0.2998, Corr: 0.5698, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3161, Corr: 0.6110, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9325225949287415
# Outer epoch 14, Inner epoch 50, Loss: 	Avg Corr: 0.2998, Corr: 0.5698, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3161, Corr: 0.6110, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9325496554374695
# Outer epoch 15, Inner epoch 10, Loss: 	Avg Corr: 0.3235, Corr: 0.6783, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3174, Corr: 0.6587, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0298599004745483
# Outer epoch 15, Inner epoch 20, Loss: 	Avg Corr: 0.3230, Corr: 0.6772, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3174, Corr: 0.6586, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0281825065612793
# Outer epoch 15, Inner epoch 30, Loss: 	Avg Corr: 0.3227, Corr: 0.6753, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3174, Corr: 0.6587, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0252385139465332
# Outer epoch 15, Inner epoch 40, Loss: 	Avg Corr: 0.3227, Corr: 0.6751, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3174, Corr: 0.6586, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.024903416633606
# Outer epoch 15, Inner epoch 50, Loss: 	Avg Corr: 0.3227, Corr: 0.6749, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3174, Corr: 0.6586, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.024627685546875
# Outer epoch 16, Inner epoch 10, Loss: 	Avg Corr: 0.3168, Corr: 0.6560, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3112, Corr: 0.6439, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0187960863113403
# Outer epoch 16, Inner epoch 20, Loss: 	Avg Corr: 0.3166, Corr: 0.6554, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3112, Corr: 0.6439, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0179489850997925
# Outer epoch 16, Inner epoch 30, Loss: 	Avg Corr: 0.3166, Corr: 0.6550, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3112, Corr: 0.6439, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0172377824783325
# Outer epoch 16, Inner epoch 40, Loss: 	Avg Corr: 0.3166, Corr: 0.6551, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3112, Corr: 0.6439, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.017406702041626
# Outer epoch 16, Inner epoch 50, Loss: 	Avg Corr: 0.3167, Corr: 0.6553, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3112, Corr: 0.6439, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.017730951309204
# Outer epoch 17, Inner epoch 10, Loss: 	Avg Corr: 0.3303, Corr: 0.7097, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3432, Corr: 0.7155, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9919246435165405
# Outer epoch 17, Inner epoch 20, Loss: 	Avg Corr: 0.3256, Corr: 0.6977, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3432, Corr: 0.7155, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9751057624816895
# Outer epoch 17, Inner epoch 30, Loss: 	Avg Corr: 0.3253, Corr: 0.6947, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3432, Corr: 0.7155, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9708947539329529
# Outer epoch 17, Inner epoch 40, Loss: 	Avg Corr: 0.3252, Corr: 0.6944, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3432, Corr: 0.7155, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9705590605735779
# Outer epoch 17, Inner epoch 50, Loss: 	Avg Corr: 0.3252, Corr: 0.6945, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3432, Corr: 0.7155, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9706759452819824
# Outer epoch 18, Inner epoch 10, Loss: 	Avg Corr: 0.2513, Corr: 0.3913, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2448, Corr: 0.3726, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0503813028335571
# Outer epoch 18, Inner epoch 20, Loss: 	Avg Corr: 0.2529, Corr: 0.3984, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2448, Corr: 0.3726, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0693570375442505
# Outer epoch 18, Inner epoch 30, Loss: 	Avg Corr: 0.2526, Corr: 0.3965, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2448, Corr: 0.3726, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0642216205596924
# Outer epoch 18, Inner epoch 40, Loss: 	Avg Corr: 0.2526, Corr: 0.3963, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2448, Corr: 0.3726, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0637673139572144
# Outer epoch 18, Inner epoch 50, Loss: 	Avg Corr: 0.2526, Corr: 0.3964, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2448, Corr: 0.3726, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0639086961746216
# Outer epoch 19, Inner epoch 10, Loss: 	Avg Corr: 0.4015, Corr: 0.9123, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.4075, Corr: 0.9304, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.98054438829422
# Outer epoch 19, Inner epoch 20, Loss: 	Avg Corr: 0.3988, Corr: 0.9048, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.4075, Corr: 0.9304, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9725105166435242
# Outer epoch 19, Inner epoch 30, Loss: 	Avg Corr: 0.3984, Corr: 0.9030, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.4075, Corr: 0.9304, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9705269932746887
# Outer epoch 19, Inner epoch 40, Loss: 	Avg Corr: 0.3982, Corr: 0.9021, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.4075, Corr: 0.9304, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9696558117866516
# Outer epoch 19, Inner epoch 50, Loss: 	Avg Corr: 0.3981, Corr: 0.9016, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.4075, Corr: 0.9304, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9690656661987305
# Outer epoch 20, Inner epoch 10, Loss: 	Avg Corr: 0.2834, Corr: 0.5168, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2902, Corr: 0.5314, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9725226759910583
# Outer epoch 20, Inner epoch 20, Loss: 	Avg Corr: 0.2753, Corr: 0.4954, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2902, Corr: 0.5314, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.932226300239563
# Outer epoch 20, Inner epoch 30, Loss: 	Avg Corr: 0.2757, Corr: 0.4958, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2902, Corr: 0.5314, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9329549074172974
# Outer epoch 20, Inner epoch 40, Loss: 	Avg Corr: 0.2757, Corr: 0.4956, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2902, Corr: 0.5314, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9326397180557251
# Outer epoch 20, Inner epoch 50, Loss: 	Avg Corr: 0.2757, Corr: 0.4956, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2902, Corr: 0.5314, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9326737523078918
# Outer epoch 21, Inner epoch 10, Loss: 	Avg Corr: 0.2566, Corr: 0.4199, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2548, Corr: 0.4209, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9976646304130554
# Outer epoch 21, Inner epoch 20, Loss: 	Avg Corr: 0.2569, Corr: 0.4208, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2548, Corr: 0.4209, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9996345043182373
# Outer epoch 21, Inner epoch 30, Loss: 	Avg Corr: 0.2571, Corr: 0.4214, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2548, Corr: 0.4209, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.001209020614624
# Outer epoch 21, Inner epoch 40, Loss: 	Avg Corr: 0.2571, Corr: 0.4217, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2548, Corr: 0.4209, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0017205476760864
# Outer epoch 21, Inner epoch 50, Loss: 	Avg Corr: 0.2571, Corr: 0.4217, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2548, Corr: 0.4209, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0018590688705444
# Outer epoch 22, Inner epoch 10, Loss: 	Avg Corr: 0.2681, Corr: 0.4640, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2678, Corr: 0.4826, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9614412188529968
# Outer epoch 22, Inner epoch 20, Loss: 	Avg Corr: 0.2667, Corr: 0.4589, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2678, Corr: 0.4826, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9508152008056641
# Outer epoch 22, Inner epoch 30, Loss: 	Avg Corr: 0.2659, Corr: 0.4579, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2678, Corr: 0.4826, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9488460421562195
# Outer epoch 22, Inner epoch 40, Loss: 	Avg Corr: 0.2658, Corr: 0.4576, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2678, Corr: 0.4826, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9480809569358826
# Outer epoch 22, Inner epoch 50, Loss: 	Avg Corr: 0.2658, Corr: 0.4575, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2678, Corr: 0.4826, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9479151964187622
# Outer epoch 23, Inner epoch 10, Loss: 	Avg Corr: 0.2210, Corr: 0.3544, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2277, Corr: 0.3744, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9466943740844727
# Outer epoch 23, Inner epoch 20, Loss: 	Avg Corr: 0.2196, Corr: 0.3508, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2277, Corr: 0.3744, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9368646144866943
# Outer epoch 23, Inner epoch 30, Loss: 	Avg Corr: 0.2191, Corr: 0.3501, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2277, Corr: 0.3744, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.935003399848938
# Outer epoch 23, Inner epoch 40, Loss: 	Avg Corr: 0.2191, Corr: 0.3499, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2277, Corr: 0.3744, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9345695376396179
# Outer epoch 23, Inner epoch 50, Loss: 	Avg Corr: 0.2191, Corr: 0.3499, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2277, Corr: 0.3744, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9345406889915466
# Outer epoch 24, Inner epoch 10, Loss: 	Avg Corr: 0.3335, Corr: 0.6365, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3429, Corr: 0.6742, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9440195560455322
# Outer epoch 24, Inner epoch 20, Loss: 	Avg Corr: 0.3276, Corr: 0.6156, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3429, Corr: 0.6742, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9131278991699219
# Outer epoch 24, Inner epoch 30, Loss: 	Avg Corr: 0.3274, Corr: 0.6149, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3429, Corr: 0.6742, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.912021815776825
# Outer epoch 24, Inner epoch 40, Loss: 	Avg Corr: 0.3273, Corr: 0.6148, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3429, Corr: 0.6742, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9118103384971619
# Outer epoch 24, Inner epoch 50, Loss: 	Avg Corr: 0.3273, Corr: 0.6146, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3429, Corr: 0.6742, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9116128087043762
# Outer epoch 25, Inner epoch 10, Loss: 	Avg Corr: 0.3194, Corr: 0.6439, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3224, Corr: 0.6591, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9769120812416077
# Outer epoch 25, Inner epoch 20, Loss: 	Avg Corr: 0.3175, Corr: 0.6362, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3224, Corr: 0.6591, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9653040170669556
# Outer epoch 25, Inner epoch 30, Loss: 	Avg Corr: 0.3180, Corr: 0.6377, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3224, Corr: 0.6591, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9675852060317993
# Outer epoch 25, Inner epoch 40, Loss: 	Avg Corr: 0.3181, Corr: 0.6383, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3224, Corr: 0.6591, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9684421420097351
# Outer epoch 25, Inner epoch 50, Loss: 	Avg Corr: 0.3182, Corr: 0.6385, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3224, Corr: 0.6591, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9687267541885376
# Outer epoch 26, Inner epoch 10, Loss: 	Avg Corr: 0.3098, Corr: 0.5248, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3132, Corr: 0.5306, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9890384078025818
# Outer epoch 26, Inner epoch 20, Loss: 	Avg Corr: 0.3076, Corr: 0.5239, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3132, Corr: 0.5306, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9874973893165588
# Outer epoch 26, Inner epoch 30, Loss: 	Avg Corr: 0.3080, Corr: 0.5239, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3132, Corr: 0.5306, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9874441623687744
# Outer epoch 26, Inner epoch 40, Loss: 	Avg Corr: 0.3080, Corr: 0.5237, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3132, Corr: 0.5306, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9870561361312866
# Outer epoch 26, Inner epoch 50, Loss: 	Avg Corr: 0.3081, Corr: 0.5238, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3132, Corr: 0.5306, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9872713685035706
# Outer epoch 27, Inner epoch 10, Loss: 	Avg Corr: 0.2899, Corr: 0.5339, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2961, Corr: 0.5475, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9751087427139282
# Outer epoch 27, Inner epoch 20, Loss: 	Avg Corr: 0.2884, Corr: 0.5301, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2961, Corr: 0.5475, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9682190418243408
# Outer epoch 27, Inner epoch 30, Loss: 	Avg Corr: 0.2888, Corr: 0.5312, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2961, Corr: 0.5475, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9701998233795166
# Outer epoch 27, Inner epoch 40, Loss: 	Avg Corr: 0.2888, Corr: 0.5314, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2961, Corr: 0.5475, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9706475138664246
# Outer epoch 27, Inner epoch 50, Loss: 	Avg Corr: 0.2889, Corr: 0.5316, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2961, Corr: 0.5475, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9710601568222046
# Outer epoch 28, Inner epoch 10, Loss: 	Avg Corr: 0.2963, Corr: 0.6299, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2970, Corr: 0.6368, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.989096999168396
# Outer epoch 28, Inner epoch 20, Loss: 	Avg Corr: 0.2988, Corr: 0.6378, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2970, Corr: 0.6368, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.001440167427063
# Outer epoch 28, Inner epoch 30, Loss: 	Avg Corr: 0.2994, Corr: 0.6398, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2970, Corr: 0.6368, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0046472549438477
# Outer epoch 28, Inner epoch 40, Loss: 	Avg Corr: 0.2997, Corr: 0.6406, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2970, Corr: 0.6368, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.005901575088501
# Outer epoch 28, Inner epoch 50, Loss: 	Avg Corr: 0.2996, Corr: 0.6403, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2970, Corr: 0.6368, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0053819417953491
# Outer epoch 29, Inner epoch 10, Loss: 	Avg Corr: 0.3354, Corr: 0.6773, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3101, Corr: 0.6071, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.1156374216079712
# Outer epoch 29, Inner epoch 20, Loss: 	Avg Corr: 0.3369, Corr: 0.6821, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3101, Corr: 0.6071, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.123602032661438
# Outer epoch 29, Inner epoch 30, Loss: 	Avg Corr: 0.3366, Corr: 0.6808, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3101, Corr: 0.6071, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.1214817762374878
# Outer epoch 29, Inner epoch 40, Loss: 	Avg Corr: 0.3364, Corr: 0.6803, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3101, Corr: 0.6071, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.120603322982788
# Outer epoch 29, Inner epoch 50, Loss: 	Avg Corr: 0.3363, Corr: 0.6801, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3101, Corr: 0.6071, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.1202563047409058
# Outer epoch 30, Inner epoch 10, Loss: 	Avg Corr: 0.3312, Corr: 0.6260, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3285, Corr: 0.6308, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9922946691513062
# Outer epoch 30, Inner epoch 20, Loss: 	Avg Corr: 0.3308, Corr: 0.6236, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3285, Corr: 0.6308, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9885389804840088
# Outer epoch 30, Inner epoch 30, Loss: 	Avg Corr: 0.3308, Corr: 0.6232, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3285, Corr: 0.6308, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9879735112190247
# Outer epoch 30, Inner epoch 40, Loss: 	Avg Corr: 0.3308, Corr: 0.6231, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3285, Corr: 0.6308, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9877306222915649
# Outer epoch 30, Inner epoch 50, Loss: 	Avg Corr: 0.3308, Corr: 0.6230, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3285, Corr: 0.6308, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9876362085342407
# Outer epoch 31, Inner epoch 10, Loss: 	Avg Corr: 0.2620, Corr: 0.4325, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2575, Corr: 0.4223, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.024106740951538
# Outer epoch 31, Inner epoch 20, Loss: 	Avg Corr: 0.2619, Corr: 0.4335, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2575, Corr: 0.4223, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0264333486557007
# Outer epoch 31, Inner epoch 30, Loss: 	Avg Corr: 0.2618, Corr: 0.4335, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2575, Corr: 0.4223, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.026387095451355
# Outer epoch 31, Inner epoch 40, Loss: 	Avg Corr: 0.2618, Corr: 0.4335, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2575, Corr: 0.4223, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0263705253601074
# Outer epoch 31, Inner epoch 50, Loss: 	Avg Corr: 0.2618, Corr: 0.4335, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2575, Corr: 0.4223, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0263677835464478
# Outer epoch 32, Inner epoch 10, Loss: 	Avg Corr: 0.3582, Corr: 0.7730, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3511, Corr: 0.7626, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0136650800704956
# Outer epoch 32, Inner epoch 20, Loss: 	Avg Corr: 0.3528, Corr: 0.7474, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3511, Corr: 0.7626, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9800335764884949
# Outer epoch 32, Inner epoch 30, Loss: 	Avg Corr: 0.3509, Corr: 0.7406, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3511, Corr: 0.7626, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9712069034576416
# Outer epoch 32, Inner epoch 40, Loss: 	Avg Corr: 0.3506, Corr: 0.7394, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3511, Corr: 0.7626, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9695723056793213
# Outer epoch 32, Inner epoch 50, Loss: 	Avg Corr: 0.3505, Corr: 0.7390, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3511, Corr: 0.7626, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9691133499145508
# Outer epoch 33, Inner epoch 10, Loss: 	Avg Corr: 0.3332, Corr: 0.6995, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3498, Corr: 0.7802, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8966015577316284
# Outer epoch 33, Inner epoch 20, Loss: 	Avg Corr: 0.3247, Corr: 0.6637, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3498, Corr: 0.7802, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8506439924240112
# Outer epoch 33, Inner epoch 30, Loss: 	Avg Corr: 0.3237, Corr: 0.6605, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3498, Corr: 0.7802, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8465452790260315
# Outer epoch 33, Inner epoch 40, Loss: 	Avg Corr: 0.3234, Corr: 0.6592, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3498, Corr: 0.7802, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8448416590690613
# Outer epoch 33, Inner epoch 50, Loss: 	Avg Corr: 0.3232, Corr: 0.6587, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3498, Corr: 0.7802, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8442953824996948
# Outer epoch 34, Inner epoch 10, Loss: 	Avg Corr: 0.2839, Corr: 0.4671, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2934, Corr: 0.4887, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9558318257331848
# Outer epoch 34, Inner epoch 20, Loss: 	Avg Corr: 0.2824, Corr: 0.4670, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2934, Corr: 0.4887, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9556770324707031
# Outer epoch 34, Inner epoch 30, Loss: 	Avg Corr: 0.2833, Corr: 0.4686, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2934, Corr: 0.4887, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9589736461639404
# Outer epoch 34, Inner epoch 40, Loss: 	Avg Corr: 0.2833, Corr: 0.4688, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2934, Corr: 0.4887, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9592825174331665
# Outer epoch 34, Inner epoch 50, Loss: 	Avg Corr: 0.2834, Corr: 0.4688, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2934, Corr: 0.4887, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9593924880027771
# Outer epoch 35, Inner epoch 10, Loss: 	Avg Corr: 0.3140, Corr: 0.5977, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3286, Corr: 0.6425, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9302796125411987
# Outer epoch 35, Inner epoch 20, Loss: 	Avg Corr: 0.3073, Corr: 0.5804, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3286, Corr: 0.6425, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9033874869346619
# Outer epoch 35, Inner epoch 30, Loss: 	Avg Corr: 0.3075, Corr: 0.5810, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3286, Corr: 0.6425, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9042654037475586
# Outer epoch 35, Inner epoch 40, Loss: 	Avg Corr: 0.3076, Corr: 0.5814, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3286, Corr: 0.6425, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9048913717269897
# Outer epoch 35, Inner epoch 50, Loss: 	Avg Corr: 0.3076, Corr: 0.5815, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3286, Corr: 0.6425, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9049805998802185
# Outer epoch 36, Inner epoch 10, Loss: 	Avg Corr: 0.2898, Corr: 0.5155, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3006, Corr: 0.5507, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9360016584396362
# Outer epoch 36, Inner epoch 20, Loss: 	Avg Corr: 0.2875, Corr: 0.5130, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3006, Corr: 0.5507, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9314876794815063
# Outer epoch 36, Inner epoch 30, Loss: 	Avg Corr: 0.2879, Corr: 0.5143, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3006, Corr: 0.5507, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9339298009872437
# Outer epoch 36, Inner epoch 40, Loss: 	Avg Corr: 0.2879, Corr: 0.5146, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3006, Corr: 0.5507, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9343805909156799
# Outer epoch 36, Inner epoch 50, Loss: 	Avg Corr: 0.2880, Corr: 0.5148, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3006, Corr: 0.5507, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9348163604736328
# Outer epoch 37, Inner epoch 10, Loss: 	Avg Corr: 0.2213, Corr: 0.3407, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2214, Corr: 0.3385, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0064128637313843
# Outer epoch 37, Inner epoch 20, Loss: 	Avg Corr: 0.2185, Corr: 0.3375, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2214, Corr: 0.3385, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9970249533653259
# Outer epoch 37, Inner epoch 30, Loss: 	Avg Corr: 0.2183, Corr: 0.3363, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2214, Corr: 0.3385, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9934815764427185
# Outer epoch 37, Inner epoch 40, Loss: 	Avg Corr: 0.2182, Corr: 0.3360, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2214, Corr: 0.3385, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9926303029060364
# Outer epoch 37, Inner epoch 50, Loss: 	Avg Corr: 0.2182, Corr: 0.3359, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2214, Corr: 0.3385, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9924042224884033
# Outer epoch 38, Inner epoch 10, Loss: 	Avg Corr: 0.2677, Corr: 0.5202, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2814, Corr: 0.5482, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9489025473594666
# Outer epoch 38, Inner epoch 20, Loss: 	Avg Corr: 0.2653, Corr: 0.5170, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2814, Corr: 0.5482, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9431519508361816
# Outer epoch 38, Inner epoch 30, Loss: 	Avg Corr: 0.2659, Corr: 0.5158, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2814, Corr: 0.5482, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9409897923469543
# Outer epoch 38, Inner epoch 40, Loss: 	Avg Corr: 0.2659, Corr: 0.5154, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2814, Corr: 0.5482, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.940220296382904
# Outer epoch 38, Inner epoch 50, Loss: 	Avg Corr: 0.2659, Corr: 0.5154, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2814, Corr: 0.5482, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9402787089347839
# Outer epoch 39, Inner epoch 10, Loss: 	Avg Corr: 0.2292, Corr: 0.3955, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2325, Corr: 0.3903, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.01320219039917
# Outer epoch 39, Inner epoch 20, Loss: 	Avg Corr: 0.2281, Corr: 0.3934, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2325, Corr: 0.3903, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0078541040420532
# Outer epoch 39, Inner epoch 30, Loss: 	Avg Corr: 0.2275, Corr: 0.3924, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2325, Corr: 0.3903, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0051970481872559
# Outer epoch 39, Inner epoch 40, Loss: 	Avg Corr: 0.2275, Corr: 0.3922, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2325, Corr: 0.3903, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.004784345626831
# Outer epoch 39, Inner epoch 50, Loss: 	Avg Corr: 0.2275, Corr: 0.3924, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2325, Corr: 0.3903, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0052766799926758
# Outer epoch 40, Inner epoch 10, Loss: 	Avg Corr: 0.3920, Corr: 0.9056, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3727, Corr: 0.7813, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.1590213775634766
# Outer epoch 40, Inner epoch 20, Loss: 	Avg Corr: 0.3933, Corr: 0.9042, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3727, Corr: 0.7813, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.157259225845337
# Outer epoch 40, Inner epoch 30, Loss: 	Avg Corr: 0.3932, Corr: 0.9018, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3727, Corr: 0.7813, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.1541903018951416
# Outer epoch 40, Inner epoch 40, Loss: 	Avg Corr: 0.3933, Corr: 0.9018, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3727, Corr: 0.7813, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.1542202234268188
# Outer epoch 40, Inner epoch 50, Loss: 	Avg Corr: 0.3933, Corr: 0.9019, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3727, Corr: 0.7813, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.1543267965316772
# Outer epoch 41, Inner epoch 10, Loss: 	Avg Corr: 0.3027, Corr: 0.5883, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2947, Corr: 0.5621, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0467453002929688
# Outer epoch 41, Inner epoch 20, Loss: 	Avg Corr: 0.2984, Corr: 0.5719, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2947, Corr: 0.5621, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0175907611846924
# Outer epoch 41, Inner epoch 30, Loss: 	Avg Corr: 0.2973, Corr: 0.5683, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2947, Corr: 0.5621, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.011090874671936
# Outer epoch 41, Inner epoch 40, Loss: 	Avg Corr: 0.2972, Corr: 0.5679, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2947, Corr: 0.5621, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0104713439941406
# Outer epoch 41, Inner epoch 50, Loss: 	Avg Corr: 0.2972, Corr: 0.5679, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2947, Corr: 0.5621, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0104327201843262
# Outer epoch 42, Inner epoch 10, Loss: 	Avg Corr: 0.2856, Corr: 0.5203, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2999, Corr: 0.5367, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9693177342414856
# Outer epoch 42, Inner epoch 20, Loss: 	Avg Corr: 0.2842, Corr: 0.5178, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2999, Corr: 0.5367, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9647403359413147
# Outer epoch 42, Inner epoch 30, Loss: 	Avg Corr: 0.2838, Corr: 0.5178, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2999, Corr: 0.5367, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9647982120513916
# Outer epoch 42, Inner epoch 40, Loss: 	Avg Corr: 0.2841, Corr: 0.5178, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2999, Corr: 0.5367, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9646732807159424
# Outer epoch 42, Inner epoch 50, Loss: 	Avg Corr: 0.2834, Corr: 0.5180, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2999, Corr: 0.5367, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9650453925132751
# Outer epoch 43, Inner epoch 10, Loss: 	Avg Corr: 0.4426, Corr: 1.0504, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3986, Corr: 0.9028, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.163515567779541
# Outer epoch 43, Inner epoch 20, Loss: 	Avg Corr: 0.4547, Corr: 1.0907, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3986, Corr: 0.9028, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.2080509662628174
# Outer epoch 43, Inner epoch 30, Loss: 	Avg Corr: 0.4541, Corr: 1.0875, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3986, Corr: 0.9028, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.2045719623565674
# Outer epoch 43, Inner epoch 40, Loss: 	Avg Corr: 0.4537, Corr: 1.0861, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3986, Corr: 0.9028, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.203013300895691
# Outer epoch 43, Inner epoch 50, Loss: 	Avg Corr: 0.4535, Corr: 1.0853, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3986, Corr: 0.9028, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.202072024345398
# Outer epoch 44, Inner epoch 10, Loss: 	Avg Corr: 0.2745, Corr: 0.4378, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# ...
# Loss ratio: 0.9827507734298706
# Outer epoch 85, Inner epoch 30, Loss: 	Avg Corr: 0.2520, Corr: 0.3858, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2501, Corr: 0.3932, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9812963604927063
# Outer epoch 85, Inner epoch 40, Loss: 	Avg Corr: 0.2520, Corr: 0.3857, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2501, Corr: 0.3932, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9809717535972595
# Outer epoch 85, Inner epoch 50, Loss: 	Avg Corr: 0.2520, Corr: 0.3857, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2501, Corr: 0.3932, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9810673594474792
# Outer epoch 86, Inner epoch 10, Loss: 	Avg Corr: 0.3268, Corr: 0.6689, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3152, Corr: 0.6154, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0869648456573486
# Outer epoch 86, Inner epoch 20, Loss: 	Avg Corr: 0.3287, Corr: 0.6738, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3152, Corr: 0.6154, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.09495210647583
# Outer epoch 86, Inner epoch 30, Loss: 	Avg Corr: 0.3282, Corr: 0.6719, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3152, Corr: 0.6154, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0918149948120117
# Outer epoch 86, Inner epoch 40, Loss: 	Avg Corr: 0.3280, Corr: 0.6712, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3152, Corr: 0.6154, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0907477140426636
# Outer epoch 86, Inner epoch 50, Loss: 	Avg Corr: 0.3280, Corr: 0.6712, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3152, Corr: 0.6154, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0906238555908203
# Outer epoch 87, Inner epoch 10, Loss: 	Avg Corr: 0.3558, Corr: 0.6915, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3506, Corr: 0.6798, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0172706842422485
# Outer epoch 87, Inner epoch 20, Loss: 	Avg Corr: 0.3557, Corr: 0.6900, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3506, Corr: 0.6798, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0150768756866455
# Outer epoch 87, Inner epoch 30, Loss: 	Avg Corr: 0.3558, Corr: 0.6906, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3506, Corr: 0.6798, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0158902406692505
# Outer epoch 87, Inner epoch 40, Loss: 	Avg Corr: 0.3558, Corr: 0.6908, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3506, Corr: 0.6798, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0161956548690796
# Outer epoch 87, Inner epoch 50, Loss: 	Avg Corr: 0.3557, Corr: 0.6904, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3506, Corr: 0.6798, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0156399011611938
# Outer epoch 88, Inner epoch 10, Loss: 	Avg Corr: 0.2428, Corr: 0.4416, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2449, Corr: 0.4399, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0036970376968384
# Outer epoch 88, Inner epoch 20, Loss: 	Avg Corr: 0.2416, Corr: 0.4355, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2449, Corr: 0.4399, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9898279309272766
# Outer epoch 88, Inner epoch 30, Loss: 	Avg Corr: 0.2425, Corr: 0.4374, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2449, Corr: 0.4399, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9942409992218018
# Outer epoch 88, Inner epoch 40, Loss: 	Avg Corr: 0.2426, Corr: 0.4375, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2449, Corr: 0.4399, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9945876002311707
# Outer epoch 88, Inner epoch 50, Loss: 	Avg Corr: 0.2426, Corr: 0.4375, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2449, Corr: 0.4399, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9944151639938354
# Outer epoch 89, Inner epoch 10, Loss: 	Avg Corr: 0.2903, Corr: 0.5167, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2840, Corr: 0.4881, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0585933923721313
# Outer epoch 89, Inner epoch 20, Loss: 	Avg Corr: 0.2866, Corr: 0.5101, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2840, Corr: 0.4881, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.045159101486206
# Outer epoch 89, Inner epoch 30, Loss: 	Avg Corr: 0.2865, Corr: 0.5091, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2840, Corr: 0.4881, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.042992353439331
# Outer epoch 89, Inner epoch 40, Loss: 	Avg Corr: 0.2865, Corr: 0.5091, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2840, Corr: 0.4881, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0431153774261475
# Outer epoch 89, Inner epoch 50, Loss: 	Avg Corr: 0.2865, Corr: 0.5091, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2840, Corr: 0.4881, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0430841445922852
# Outer epoch 90, Inner epoch 10, Loss: 	Avg Corr: 0.2815, Corr: 0.5146, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2681, Corr: 0.4634, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.1106305122375488
# Outer epoch 90, Inner epoch 20, Loss: 	Avg Corr: 0.2793, Corr: 0.5038, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2681, Corr: 0.4634, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0873554944992065
# Outer epoch 90, Inner epoch 30, Loss: 	Avg Corr: 0.2784, Corr: 0.4999, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2681, Corr: 0.4634, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0789231061935425
# Outer epoch 90, Inner epoch 40, Loss: 	Avg Corr: 0.2783, Corr: 0.4996, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2681, Corr: 0.4634, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.078189492225647
# Outer epoch 90, Inner epoch 50, Loss: 	Avg Corr: 0.2782, Corr: 0.4994, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2681, Corr: 0.4634, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0777416229248047
# Outer epoch 91, Inner epoch 10, Loss: 	Avg Corr: 0.4179, Corr: 0.9462, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.4082, Corr: 0.9187, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0300213098526
# Outer epoch 91, Inner epoch 20, Loss: 	Avg Corr: 0.4144, Corr: 0.9272, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.4082, Corr: 0.9187, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0093483924865723
# Outer epoch 91, Inner epoch 30, Loss: 	Avg Corr: 0.4141, Corr: 0.9263, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.4082, Corr: 0.9187, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0083025693893433
# Outer epoch 91, Inner epoch 40, Loss: 	Avg Corr: 0.4141, Corr: 0.9261, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.4082, Corr: 0.9187, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0081253051757812
# Outer epoch 91, Inner epoch 50, Loss: 	Avg Corr: 0.4141, Corr: 0.9261, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.4082, Corr: 0.9187, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0081111192703247
# Outer epoch 92, Inner epoch 10, Loss: 	Avg Corr: 0.2343, Corr: 0.3939, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2428, Corr: 0.4053, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9716472625732422
# Outer epoch 92, Inner epoch 20, Loss: 	Avg Corr: 0.2331, Corr: 0.3879, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2428, Corr: 0.4053, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9569785594940186
# Outer epoch 92, Inner epoch 30, Loss: 	Avg Corr: 0.2334, Corr: 0.3876, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2428, Corr: 0.4053, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9562596082687378
# Outer epoch 92, Inner epoch 40, Loss: 	Avg Corr: 0.2335, Corr: 0.3877, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2428, Corr: 0.4053, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9563646912574768
# Outer epoch 92, Inner epoch 50, Loss: 	Avg Corr: 0.2335, Corr: 0.3877, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2428, Corr: 0.4053, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9563696384429932
# Outer epoch 93, Inner epoch 10, Loss: 	Avg Corr: 0.2356, Corr: 0.3688, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2425, Corr: 0.3723, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9907865524291992
# Outer epoch 93, Inner epoch 20, Loss: 	Avg Corr: 0.2343, Corr: 0.3673, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2425, Corr: 0.3723, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9866087436676025
# Outer epoch 93, Inner epoch 30, Loss: 	Avg Corr: 0.2343, Corr: 0.3674, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2425, Corr: 0.3723, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9870220422744751
# Outer epoch 93, Inner epoch 40, Loss: 	Avg Corr: 0.2343, Corr: 0.3675, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2425, Corr: 0.3723, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.987331211566925
# Outer epoch 93, Inner epoch 50, Loss: 	Avg Corr: 0.2343, Corr: 0.3676, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2425, Corr: 0.3723, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9873682260513306
# Outer epoch 94, Inner epoch 10, Loss: 	Avg Corr: 0.2928, Corr: 0.5356, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3008, Corr: 0.5342, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.002610445022583
# Outer epoch 94, Inner epoch 20, Loss: 	Avg Corr: 0.2879, Corr: 0.5323, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3008, Corr: 0.5342, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9964836835861206
# Outer epoch 94, Inner epoch 30, Loss: 	Avg Corr: 0.2882, Corr: 0.5293, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3008, Corr: 0.5342, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9908551573753357
# Outer epoch 94, Inner epoch 40, Loss: 	Avg Corr: 0.2883, Corr: 0.5290, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3008, Corr: 0.5342, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9901843070983887
# Outer epoch 94, Inner epoch 50, Loss: 	Avg Corr: 0.2883, Corr: 0.5287, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3008, Corr: 0.5342, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9897528290748596
# Outer epoch 95, Inner epoch 10, Loss: 	Avg Corr: 0.2895, Corr: 0.6110, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2833, Corr: 0.6111, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9997265934944153
# Outer epoch 95, Inner epoch 20, Loss: 	Avg Corr: 0.2916, Corr: 0.6115, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2833, Corr: 0.6111, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0006352663040161
# Outer epoch 95, Inner epoch 30, Loss: 	Avg Corr: 0.2913, Corr: 0.6115, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2833, Corr: 0.6111, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0006396770477295
# Outer epoch 95, Inner epoch 40, Loss: 	Avg Corr: 0.2913, Corr: 0.6115, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2833, Corr: 0.6111, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0005990266799927
# Outer epoch 95, Inner epoch 50, Loss: 	Avg Corr: 0.2912, Corr: 0.6115, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2833, Corr: 0.6111, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0005968809127808
# Outer epoch 96, Inner epoch 10, Loss: 	Avg Corr: 0.3457, Corr: 0.7542, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3641, Corr: 0.8090, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9323316216468811
# Outer epoch 96, Inner epoch 20, Loss: 	Avg Corr: 0.3407, Corr: 0.7373, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3641, Corr: 0.8090, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9113925695419312
# Outer epoch 96, Inner epoch 30, Loss: 	Avg Corr: 0.3420, Corr: 0.7393, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3641, Corr: 0.8090, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9139365553855896
# Outer epoch 96, Inner epoch 40, Loss: 	Avg Corr: 0.3423, Corr: 0.7396, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3641, Corr: 0.8090, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9142449498176575
# Outer epoch 96, Inner epoch 50, Loss: 	Avg Corr: 0.3422, Corr: 0.7395, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3641, Corr: 0.8090, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.914082407951355
# Outer epoch 97, Inner epoch 10, Loss: 	Avg Corr: 0.3508, Corr: 0.6969, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3132, Corr: 0.5906, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.1800225973129272
# Outer epoch 97, Inner epoch 20, Loss: 	Avg Corr: 0.3594, Corr: 0.7236, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3132, Corr: 0.5906, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.225239872932434
# Outer epoch 97, Inner epoch 30, Loss: 	Avg Corr: 0.3586, Corr: 0.7219, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3132, Corr: 0.5906, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.2224442958831787
# Outer epoch 97, Inner epoch 40, Loss: 	Avg Corr: 0.3582, Corr: 0.7208, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3132, Corr: 0.5906, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.2205888032913208
# Outer epoch 97, Inner epoch 50, Loss: 	Avg Corr: 0.3584, Corr: 0.7215, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3132, Corr: 0.5906, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.2217254638671875
# Outer epoch 98, Inner epoch 10, Loss: 	Avg Corr: 0.2312, Corr: 0.3823, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2379, Corr: 0.3981, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9603334665298462
# Outer epoch 98, Inner epoch 20, Loss: 	Avg Corr: 0.2295, Corr: 0.3748, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2379, Corr: 0.3981, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.941529393196106
# Outer epoch 98, Inner epoch 30, Loss: 	Avg Corr: 0.2294, Corr: 0.3753, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2379, Corr: 0.3981, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9428541660308838
# Outer epoch 98, Inner epoch 40, Loss: 	Avg Corr: 0.2294, Corr: 0.3756, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2379, Corr: 0.3981, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9435597658157349
# Outer epoch 98, Inner epoch 50, Loss: 	Avg Corr: 0.2294, Corr: 0.3756, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2379, Corr: 0.3981, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9435805678367615
# Outer epoch 99, Inner epoch 10, Loss: 	Avg Corr: 0.3194, Corr: 0.6003, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3149, Corr: 0.5891, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.018902063369751
# Outer epoch 99, Inner epoch 20, Loss: 	Avg Corr: 0.3175, Corr: 0.6001, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3149, Corr: 0.5891, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.018548607826233
# Outer epoch 99, Inner epoch 30, Loss: 	Avg Corr: 0.3169, Corr: 0.5973, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3149, Corr: 0.5891, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0138025283813477
# Outer epoch 99, Inner epoch 40, Loss: 	Avg Corr: 0.3169, Corr: 0.5972, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3149, Corr: 0.5891, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0136224031448364
# Outer epoch 99, Inner epoch 50, Loss: 	Avg Corr: 0.3169, Corr: 0.5969, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.3149, Corr: 0.5891, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0131444931030273

# %%
with torch.no_grad():
    # Regularization and weight decay
    # rate=-1, n_track=n_update=10 reduces correlations by 50%, better than rate=-2
    # Updating multiple times per epoch decreases loss below regular inner epoch formulation (if we set inner epochs = 50, only way to get it to decorrelate is to increase n_track and n_update)
    plt.plot(torch.arange(losses.shape[0]), losses, label="rate1inner50track10update10")
    plt.legend()
    plt.xlabel("Epoch")
    plt.ylabel("Loss ratio")
    plt.title("Loss ratio per realization over time")
    plt.show()

# %%
i = correlated_mitral_activity()
hbar_ff = compute_feedforward_activity(i)
W_random = compute_initial_recurrent_weights()
R_random = compute_piriform_response(hbar_ff, W_random, threshold_multiplier)

# %%
# Look at how weights evolve over the course of inner epoch, for a random realization
# Store a random set of 10 weights and see how the 10 weights change over the course of the iterations

# %%
with torch.no_grad():
    plt.hist(torch.flatten(R_random[:num_e]), density=True, label="E responses")
    plt.hist(torch.flatten(R_random[num_e:]), density=True, label="I responses")
    plt.legend()
    plt.show()

# %%
with torch.no_grad():
    sparsities = sparsity_per_odor(R_random)
    spars_novel = sparsities[novel_inds]
    spars_familiar = sparsities[familiar_inds]
    plt.hist(spars_novel, density=True, label="Novel")
    plt.hist(spars_familiar, density=True, label="Familiar")
    plt.title("Sparsity per odor for novel vs familiar, before plasticity")
    plt.legend()
    plt.show()

# %%
# TODO add I to E training
# Save the model for each regime we test (so we can retrieve the colormap)
# Re-run it again or twice (just to verify model trains in same way)
# - First only train I to E (and keep E to I fixed, as sanity check)
# - First try w/o regularization term, then add it (functionality should be same as E to I)
# - Want weights to blow up negatively (such that E input would be very small and below ReLU threshold, so it creates sparsity concept)
# - Optimize it jointly to E to I (the W_ei weights will also have a gradient so we can update its model)
# Use a separate model
# Train it only on portion of responses the model actually sees (I: 0-1, E: 0-2)
# Make sure its not overfitting but that the R^2 is high enough
# Empirically looks like E^2 + I^2 (and changes faster in I direction)
# As sparsity regularization parameter changes, see how the regression parameters would change

# %%
# path = "./ie_only/5"
# torch.save(model.state_dict(), path)
#model = create_model()
#model.load_state_dict(torch.load(path))

# %%
def make_colormap(model):
    num_ticks = 100
    E_min, E_max = torch.min(R_random[:num_e, :]), torch.max(R_random[:num_e, :])
    I_min, I_max = torch.min(R_random[num_e:, :]), torch.max(R_random[num_e:, :])
    E_vals = torch.linspace(E_min, E_max, num_ticks)
    I_vals = torch.linspace(I_min, I_max, num_ticks)
    E_coords, I_coords = torch.meshgrid(E_vals, I_vals, indexing="ij")
    R_plot = torch.stack((E_coords.flatten(), I_coords.flatten()), dim=1)
    with torch.no_grad():
        plasticity_vals = model(R_plot).squeeze(0)
        
    plot = plt.scatter(R_plot[:, 0], R_plot[:, 1], c=plasticity_vals, cmap='rainbow')
    clrbar = plt.colorbar(plot)
    clrbar.set_label('Model plasticity')
    plt.title('E-I plasticity based on neural responses')
    plt.xlabel("E responses")
    plt.ylabel("I responses")
        
    return E_min, E_max, I_min, I_max, R_plot, plasticity_vals

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline

def fit_model(model, degree=3):
    E_min, E_max, I_min, I_max, R_plot, plasticity_vals = make_colormap(model)
    
    
    std = 2 # Take data within 2 std of responses mean
    mu_e = torch.mean(torch.flatten(R_random[:num_e]))
    sig_e = torch.std(torch.flatten(R_random[:num_e]))
    mu_i = torch.mean(torch.flatten(R_random[num_e:]))
    sig_i = torch.std(torch.flatten(R_random[num_e:]))
    e_train_bounds = (torch.max(E_min, mu_e - std*sig_e), torch.min(E_max, mu_e + std*sig_e))
    i_train_bounds = (torch.max(I_min, mu_i - std*sig_i), torch.min(I_max, mu_i + std*sig_i))
    
    reg = Pipeline([('poly', PolynomialFeatures(degree=degree)),
                  ('linear', LinearRegression(fit_intercept=False))])
    
    e_inds = torch.logical_and(torch.ge(R_plot[:, 0], e_train_bounds[0]), torch.le(R_plot[:, 0], e_train_bounds[1]))
    i_inds = torch.logical_and(torch.ge(R_plot[:, 1], i_train_bounds[0]), torch.le(R_plot[:, 1], i_train_bounds[1]))
    b = torch.logical_and(e_inds, i_inds)
    X = R_plot[b]
    y = plasticity_vals[b].squeeze(0)
    
    reg = reg.fit(X, y)
    # Exclude bias term
    coefs = reg.named_steps['linear'].coef_[0][1:]
    # How many terms to consider
    take = 3
    # Take largest magnitude terms
    inds = np.argsort(np.abs(coefs))[-take:]

    # Exclude bias term
    term_list = reg.named_steps['poly'].powers_[1:, :]
    terms = f"[E, I] powers:\n"
    for i in range(take - 1, -1, -1):
        term = f"{term_list[inds][i]}: {coefs[inds][i]}\n"
        terms += term
    
    print(terms)
    
    preds = reg.predict(X).ravel()
    return X, preds

# %%
X, preds = fit_model(model, degree=3)

pred_plot = plt.scatter(X[:, 0], X[:, 1], c=preds, cmap='rainbow')
clrbar2 = plt.colorbar(pred_plot)
clrbar2.set_label('Predicted')
plt.xlabel("E responses")
plt.ylabel("I responses")
plt.show()
# Out:
# [E, I] powers:
# [0 1]: -0.15797385793911764
# [2 0]: 0.13613606188691962
# [1 0]: 0.13045914491230948

# %%
# Do a plot of rho_0 vs rho_final (for ex. 100 random initializations) to see whether the model can decorrelate odors
# Even though potentiation is always positive for the set of responses, since we are doing E to I, increasing the connection strength effectively increases inhibition too, so it balances out
# Not directly hebbian because that would mean there is some constant c*r_i*r_j, but when one of the responses is decreasing, the resulting potentiation doesn't decrease
# Instead, it will be an a * r_i + b * r_j term
# These terms come from the polynomial expansion of the function defined by the model

# %%
# Look at statistics of E neurons (mean firing rate across odors, variance, etc) at initialization compared to after plasticity
# Also look at sparsity - one across odors and another across neurons (sparsity is essentially 1 minus the square of the coefficient of variation)
# We care mostly about the sparsity across neurons (ex between neurons) and what it would be between odors (should be similar between the familiar odors b/c that's where we applied the plasticity) and we also know what it's like between novel odors
# We don't want a change in firing rate, because it should be same for novel and familiar odors

# %%
def verification_set(model, runs=20):
    corrs = torch.empty((runs,))
    ratios = torch.empty((runs,))
    spars_change = torch.empty((runs,))
    for i in range(runs):
        I_ff = correlated_mitral_activity()
        hbar_ff = compute_feedforward_activity(I_ff)
        W_random = compute_initial_recurrent_weights()
        R_random = compute_piriform_response(hbar_ff, W_random, threshold_multiplier)
        _, initial_corr = odor_corrs(R_random)
        spars_initial = sparsity_per_odor(R_random)
        initial_spars_diff = torch.abs(torch.mean(spars_initial[novel_inds]) - torch.mean(spars_initial[familiar_inds]))
        
        post = (num_e, num_neurons)
        pre = (0, num_e)
        weights_slice = W_random[post[0]:post[1], pre[0]:pre[1]]
        inds = torch.nonzero(weights_slice, as_tuple=True)
        update_inds = (inds[0] + post[0], inds[1] + pre[0])
        
        for _ in range(n_inner):
            _, W_random, R_random = loss_after_odors(model, W_random, R_random, hbar_ff, threshold_multiplier, plasticity_rate, weight_decay, update_inds, lambda_corr, lambda_mu, lambda_var, lambda_sp, detach_grad=True, with_loss=False)
        
        _, final_corr = odor_corrs(R_random)
        ratio = final_corr / initial_corr
        spars_final = sparsity_per_odor(R_random)
        # Plot actual difference in the sparsity number, not the percent change ratio
        # - Also see whether 
        final_spars_diff = torch.abs(torch.mean(spars_final[novel_inds]) - torch.mean(spars_final[familiar_inds]))
        
        print(f"Corr: {initial_corr} -> {final_corr}, Sparsity: {initial_spars_diff} -> {final_spars_diff}, Loss Ratio: {ratio}")
        corrs[i] = final_corr
        ratios[i] = ratio
        spars_change[i] = ((final_spars_diff - initial_spars_diff) / initial_spars_diff) * 100
        
    return corrs, ratios, spars_change

# %%
with torch.no_grad():
    corrs, ratios, spars_change = verification_set(model, runs=10)
# Out:
# Corr: 0.2198134809732437 -> 0.21933400630950928, Sparsity: 0.0734742283821106 -> 0.1086958646774292, Loss Ratio: 0.9978187084197998
# Corr: 0.3648258149623871 -> 0.36974871158599854, Sparsity: 0.03304719924926758 -> 0.041134536266326904, Loss Ratio: 1.0134937763214111
# Corr: 0.2858160138130188 -> 0.2698534429073334, Sparsity: 0.04236435890197754 -> 0.011033475399017334, Loss Ratio: 0.9441508650779724
# Corr: 0.26479676365852356 -> 0.2499588429927826, Sparsity: 0.07503801584243774 -> 0.059812724590301514, Loss Ratio: 0.9439648985862732
# Corr: 0.2654520273208618 -> 0.2633044123649597, Sparsity: 0.06301373243331909 -> 0.033807575702667236, Loss Ratio: 0.9919095635414124
# Corr: 0.28714519739151 -> 0.2953735291957855, Sparsity: 0.13674956560134888 -> 0.07833218574523926, Loss Ratio: 1.0286556482315063
# Corr: 0.2663941979408264 -> 0.26544833183288574, Sparsity: 0.03156697750091553 -> 0.0021597743034362793, Loss Ratio: 0.99644935131073
# Corr: 0.38898006081581116 -> 0.375978022813797, Sparsity: 0.08650696277618408 -> 0.03780949115753174, Loss Ratio: 0.9665740132331848
# Corr: 0.24743176996707916 -> 0.23153376579284668, Sparsity: 0.05047643184661865 -> 0.02935558557510376, Loss Ratio: 0.9357479214668274
# Corr: 0.26242974400520325 -> 0.2500373423099518, Sparsity: 0.11437302827835083 -> 0.09568989276885986, Loss Ratio: 0.9527782201766968

# %%
plt.hist(ratios, bins=20)
plt.title("Loss ratios")
plt.show()
plt.hist(spars_change, bins=20)
plt.title("Percent change in sparsity per odor")
plt.show()

# %%
spars_change[spars_change < 100]
# Out:
# tensor([ 47.9374,  24.4721, -73.9558, -20.2901, -46.3489, -42.7185, -93.1581,
#         -56.2931, -41.8430, -16.3353])

# %%
# Stats at initialization
i = correlated_mitral_activity()
hbar_ff = compute_feedforward_activity(i)
with torch.no_grad():
    W_random = compute_initial_recurrent_weights()
    R_random = compute_piriform_response(hbar_ff, W_random, threshold_multiplier)
mu_familiar_0 = torch.mean(R_random[:num_e, familiar_inds], dim=1)
sig_familiar_0 = torch.var(R_random[:num_e, familiar_inds], dim=1)
mu_novel_0 = torch.mean(R_random[:num_e, novel_inds], dim=1)
sig_novel_0 = torch.var(R_random[:num_e, novel_inds], dim=1)
#print(f"Initialization: \nFamiliar -  mean: {mu_familiar_0}, var: {sig_familiar_0}\nNovel -  mean: {mu_novel_0}, var: {sig_novel_0}")

# %%
# Stats after plasticity
W_plastic = W_random.detach().clone()
R_plastic = R_random.detach().clone()
post = (num_e, num_neurons)
pre = (0, num_e)
weights_slice = W_random[post[0]:post[1], pre[0]:pre[1]]
inds = torch.nonzero(weights_slice, as_tuple=True)
update_inds = (inds[0] + post[0], inds[1] + pre[0])

# Number of weights to track
num_samples = 100
W_tracked = torch.empty((n_inner, num_samples))
with torch.no_grad():
    for i in range(n_inner):
        _, W_plastic, R_plastic = loss_after_odors(model, W_plastic, R_plastic, hbar_ff, threshold_multiplier, plasticity_rate, weight_decay, update_inds, lambda_corr, lambda_mu, lambda_var, lambda_sp, detach_grad=True, with_loss=False)
        track_inds = torch.randint(0, len(update_inds), size=(num_samples,))
        W_tracked[i, :] = W_plastic[update_inds][track_inds].detach()
        
mu_familiar_f = torch.mean(R_plastic[:num_e, familiar_inds], dim=1)
sig_familiar_f = torch.var(R_plastic[:num_e, familiar_inds], dim=1)
mu_novel_f = torch.mean(R_plastic[:num_e, novel_inds], dim=1)
sig_novel_f = torch.var(R_plastic[:num_e, novel_inds], dim=1)
mu_novel_diff = mu_novel_f - mu_novel_0
mu_familiar_diff = mu_familiar_f - mu_familiar_0
sig_novel_diff = sig_novel_f - sig_novel_0
sig_familiar_diff = sig_familiar_f - sig_familiar_0

# %%
with torch.no_grad():
    loss_fn(R_random, lambda_corr, lambda_mu, lambda_var, lambda_sp)
    loss_fn(R_plastic, lambda_corr, lambda_mu, lambda_var, lambda_sp)
# Out:
# Avg Corr: 0.2920, Corr: 0.5465, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Avg Corr: 0.2962, Corr: 0.5884, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000

# %%
with torch.no_grad():
    pct_change = ((W_tracked - w_ie) / w_ie) * 100
    plt.plot(pct_change)
    plt.xlabel("Inner epochs")
    plt.ylabel("Weight percent change")

# %%
plt.hist(mu_familiar_0 - mu_novel_0, bins=50, label="Before")
plt.hist(mu_familiar_f - mu_novel_f, bins=50, label="After")
plt.legend()
plt.show()

# %%
plt.hist(mu_novel_diff, bins=50, label="Novel")
plt.hist(mu_familiar_diff, bins=50, label="Familiar")
plt.title("Difference in mean responses before and after plasticity")
plt.legend()
plt.show()
# TODO find difference in familiar and novel (before plasticity) and then compare to diff (after plasticity)

# %%
weights_slice = W_random[post[0]:post[1], pre[0]:pre[1]]
inds = torch.nonzero(weights_slice, as_tuple=True)
update_inds = (inds[0] + post[0], inds[1] + pre[0])

# %%
W_change = ((W_plastic[update_inds] - W_random[update_inds]) / W_random[update_inds]) * 100
plt.hist(W_change, bins=50)
plt.title("Percent weight change from initialization")
plt.show()
# Most weight

# %%
sp_novel_0 = sparsity_per_neuron(R_random, novel_inds)
sp_novel_f = sparsity_per_neuron(R_plastic, novel_inds)
sp_familiar_0 = sparsity_per_neuron(R_random, familiar_inds)
sp_familiar_f = sparsity_per_neuron(R_plastic, familiar_inds)

# %%
with torch.no_grad():
    plt.hist(sp_novel_0, cumulative=True, bins=num_e, histtype="step", label="Novel_0")
    plt.hist(sp_familiar_0, cumulative=True, bins=num_e, histtype="step", label="Familiar_0")
    plt.hist(sp_novel_f, cumulative=True, bins=num_e, histtype="step", label="Novel_f")
    plt.hist(sp_familiar_f, cumulative=True, bins=num_e, histtype="step", label="Familiar_f")
    plt.legend()
    plt.show()

# %%
# Create scatter plot of odor correlation vs sparsity difference - odors that are highly positively correlated should have similar sparsities across neurons, and those that are highly negatively correlated should have different sparsities across neurons
# Check - increase P' all the way to 16, and with lower correlations, there should be less variability between the sparsity for each odor
# - would tell us how much the natural spread in sparsity is

# %%
# 1. Re-run model w/ lower threshold (0 stdev above mean)
# 2. Figure out percentage-wise how much the weights actually change (do a hist)
# - if it's 1-2% it's too small, we want the weights to change 10-100%, the weights could even change 10-fold
# 3. Add metrics to training function - automatically compute sparsity etc (also look at the sparsity between odors, not just the sparsity between neurons, see if it changes for novel vs familiar)
# Create bar plot for each number of odors, how many neurons respond to that number of odors (ideally, if we have a threshold of 0 stdev, most neurons should respond to ~4 odors, since on average a neuron will respond to half of the total odors, so 8 odors, and out of those, it should be equal between 4 novel and 4 familiar)
# Hypothesis right now - weights aren't changing that much, so we can add more epoch_inner steps (since the gradient isn't blowing up)
# Then, try removing plasticity ramp - keep 1e-3 (don't do epoch_inner increase and remove plasticity ramp at same time)
# Goal: understand what mechanism the meta-learning discovered that makes correlations smaller (see whether it acts on sparsity etc)
# Think of other metrics to quantify network behavior to understand change
