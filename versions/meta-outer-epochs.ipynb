# %%
# !pip install numpy
# !pip install scipy
# !pip install torch
# !pip install matplotlib

# %%
import torch
import numpy as np
import scipy
import matplotlib.pyplot as plt

# %%
# Use smaller network for testing - ex 2000 neurons
# Even for the project, doing it for 10^6 neurons would take too long
# Problem this creates: test network is denser than actual network b/c we have 10^3 neurons but 10^2 connections per neuron
num_neurons = 2000
num_i = int(0.1 * num_neurons)
num_e = int(0.9 * num_neurons)

# Num excitatory inputs and inhibitory inputs to each neuron (in reality it should be 500 but we reduce it here to make things faster)
k = 100

# Number of olfactory bulb channels (glomeruli) to each neuron
D = 10 ** 3
# For each neuron, how many glomeruli inputs it receives (should be 10^2)
num_channel_inputs = 100

# Channel signal if not active for odor a
i_0 = 2.
# Channel signal if active for odor a
i_1 = 10.
# Probability that a channel is active for an odor a
f = 0.1
# Number of odors
P = 16
# Novel activity is up to P // 2, and familiar activity is after
novel_inds = torch.arange(0, P // 2)
familiar_inds = torch.arange(P // 2, P)

# %%
# Creates sparse adjacency matrix with the given probability of edge connection and size mxn
def create_adj_matrix(p, m, n):
    num_connections = int(p * m * n)
    m_coords = torch.randint(0, m, (num_connections,))
    n_coords = torch.randint(0, n, (num_connections,))
    indices = torch.vstack((m_coords, n_coords))
    values = torch.ones(num_connections)
    A_mn = torch.sparse_coo_tensor(indices, values, (m, n))
    return A_mn

# %%
# Draws mitral activity from exponential distribution (by default the rate is 1 / f, so the mean becomes f)
# Otherwise this exponential distribution drops off too quickly
# def compute_mitral_activity(rate=1/f):
#     # Generate new sample for each odor
#     dist = torch.distributions.Exponential(rate).expand(torch.Size([D]))
#     probs = dist.sample(sample_shape=(P,))
#     probs.t_()
#     probs[probs > 1] = 1
#     I = torch.bernoulli(probs) * (i_1 - i_0) + i_0
#     return I

# %%
# Epsilon value defining correlation amount between odors, e < 1, e=0.5
# def correlated_mitral_activity(e):
#     # Covariance matrix representing initial correlations between odors
#     Sigma_0 = torch.ones((P, P)) * e
#     # Each odor has variance 1 (the diagonal represents variances)
#     Sigma_0.fill_diagonal_(1)
#     dist = torch.distributions.MultivariateNormal(torch.zeros(P), Sigma_0)
#     activity = dist.sample(torch.Size([D]))
#     return activity

# %%
# New way of generating correlations between odors: we want different sets of odors to be correlated differently, so that when we subtract each neuron's mean activity over odors, it doesn't cancel out the variation between odors (if all the odors are correlated the same, they will tend to produce similar values for a single neuron and therefore subtracting by the mean will remove these values and only leave small fluctuations)
# So we sample a small set of odors P' and make them linearly independent, and then by multiplying by a P'x P gaussian matrix we project into mitral cell activity space for all P odors, basically making the P odors a linear combination of the set of P' odors (the smaller P' is, the more correlated the resulting set of P odors will be)
# We also scale the variance depending on how small P' is, so we will maintain differently correlated odors, just with higher total correlation if P' is small

# %%
P_prime = 4
def correlated_mitral_activity():
    # Each of the P' odors is independent (correlation of 0)
    sigma_p_prime = torch.zeros((P_prime, P_prime)).fill_diagonal_(1)
    dist = torch.distributions.MultivariateNormal(torch.zeros(P_prime), sigma_p_prime)
    p_prime_activity = dist.sample(torch.Size([D]))
    var = 1 / P_prime
    projection = torch.normal(torch.zeros((P_prime, P)), torch.ones(P_prime, P) * np.sqrt(var))
    activity = p_prime_activity @ projection
    return activity

# %%
# Draws random activity with probability f
def compute_random_mitral_activity():
    I = torch.distributions.Bernoulli(f).sample(torch.Size((D, P))) * (i_1 - i_0) + i_0
    
    return I

# %%
# Takes in mitral activity I and computes feedforward activity h_bar_ff
def compute_feedforward_activity(I):
    # Probability that a channel weight will be nonzero
    p = num_channel_inputs / D
    # Only the first 0.9 * n rows should have this bernoulli number, the rest should be 0 b/c they don't receive a channel input
    # Check whether each neuron still receives ~10^2 nonzero inputs or what the distribution actually looks like
    # Because when we calculate the adjacency matrix we don't go by row (e.g ensuring each neuron has these ~10^2 connections)
    # Alternative: sample from Binomial distribution w/ mean 100
    # The output n for each row is the number of nonzero inputs, and you choose a random subset n of the indices for that row and make them 1
    a = create_adj_matrix(p, num_e, D)
    # Inhibitory neurons don't receive channel input
    # This is the first simplification, where we neglect the first inhibitory layer I_ff
    b = torch.zeros(size=(num_i, D)).to_sparse()
    W_ff = torch.cat(tensors=(a, b), dim=0)
    
    h_ff = (W_ff @ I) * (1 / np.sqrt(num_channel_inputs))
    h_bar_ff = h_ff - torch.mean(h_ff, dim=0, keepdim=True)
    return h_bar_ff

# %%
def compute_initial_recurrent_weights():
    k_ee = k_ei = k_ie = k_ii = k
    #p_ee = k_ee / num_e
    # k inhibitory inputs to that e neuron, out of num_i total inhibitory neurons gives the connection probability per neuron
    p_ei = k_ei / num_i
    p_ie = k_ie / num_e
    #p_ii = k_ii / num_i
    
    # Constants
    #w_ee = 0.1
    w_ei = 0.2
    w_ie = 0.5
    #w_ii = 0.3
    # Ignore ee and ii weights for now:
    p_ee = p_ii = w_ee = w_ii = 0
    W_ee = create_adj_matrix(p_ee, num_e, num_e) * w_ee
    W_ei = create_adj_matrix(p_ei, num_e, num_i) * -w_ei
    W_ie = create_adj_matrix(p_ie, num_i, num_e) * w_ie
    W_ii = create_adj_matrix(p_ii, num_i, num_i) * -w_ii
    
    # Concat
    W_1 = torch.cat(tensors=(W_ee, W_ei), dim=1)
    W_2 = torch.cat(tensors=(W_ie, W_ii), dim=1)
    W_rec = torch.cat(tensors=(W_1, W_2), dim=0)
    
    # For now, use dense tensor because sparse tensor has issues w/ autograd
    W_rec = W_rec.to_dense()
    
    return W_rec

# %%
# Computes activation threshold for neurons, based on the standard deviation of their firing rates across odors
# This average standard deviation, multiplied by theta=2, ensures that each neuron will fire for only 5% of odors
def compute_threshold(total_input, theta):
    # For now, use diff thresholds for each neuron
    center = torch.mean(total_input, dim=1, keepdim=True)
    shift = torch.std(total_input, dim=1, keepdim=True)
    threshold = center + (theta * shift)
    # Since inhibitory neurons are linear
    threshold[num_e:, :] = 0
    return threshold

# %%
# ReLU for excitatory, linear for inhibitory
def neuron_activations(X):
    # Mask to keep excitatory
    mask1 = torch.ones((num_neurons, 1))
    mask1[num_e:, :] = 0
    # Mask to keep inhibitory
    mask2 = torch.zeros((num_neurons, 1))
    mask2[num_e:, :] = 1
    return (torch.relu(X) * mask1) + (X * mask2)

# %%
# Computes R for each odor, with the activation threshold theta
def compute_piriform_response(h_bar_ff, W_rec, threshold_mult):
    # The coefficient of x_bar
    tau = 1
    # time step
    dt = 0.1
    # Number of time steps
    T = 200
    
    # Initial condition where states are gaussian
    mu_0 = 0.
    sigma_0 = 0.2
    X_0 = torch.normal(mu_0, sigma_0, size=(num_neurons, P))
    X = X_0
    
    pts = []
    for i in range(T-1):
        with torch.no_grad():
            part1 = -1 * X
            part2 = (W_rec @ neuron_activations(X)) * (1 / np.sqrt(k))
            part3 = h_bar_ff
            dXdt = (1 / tau) * (part1 + part2 + part3)
            X = X + (dXdt * dt)
        # Look at convergence pattern for first odor, assuming that it'll
        # be similar across odors (since they are all independent)
        #pts.append(torch.mean(dXdt, dim=0)[0].item())
   
    # On the last iteration only, track the gradient
    X.requires_grad_(True)
    
    part1 = -1 * X
    part2 = (W_rec @ neuron_activations(X)) * (1 / np.sqrt(k))
    part3 = h_bar_ff
    with torch.no_grad():
        # The total input to the neuron at this last time step (should be equivalent to the resulting value of X after this time step, since dxdt = 0 after the recurrent network converges)
        total_input = part2 + part3
        threshold = compute_threshold(total_input, threshold_mult)
    
    dXdt = (1 / tau) * (part1 + part2 + part3)
    X = X + (dXdt * dt)
    # Plot derivatives to see if state converged
    # plt.plot(torch.arange(T-1), pts)
    # plt.show()
    R = neuron_activations(X - threshold)
    
    return R

# %%
# Compute dimensionality of activity matrix R for either novel or familiar
def compute_dim(R, odor_inds):
    # Only compute for the excitatory neurons (b/c those are the ones that send signals to rest of brain
    C = torch.cov(R[:num_e, odor_inds[0]:odor_inds[-1]])
    dim = torch.trace(C) ** 2 / torch.trace(C @ C)
    return dim

# trace() is invariant for cyclic permutations of a matrix
# Since C is symmetric, it can be orthogonally diagonalized into UDU^T where U is composed of orthonormal eigenvectors, U^T = U^-1, and D is a diagonal matrix of eigenvalues
# therefore, trace(C) = trace(UDU^T) = trace(DU^TU) = trace(D) = sum(eigvals of C)
# Similarly for the denominator, we need to compute the sum of the squared eigenvalues, which is trace(D^2). trace(D^2) = trace(D^2U^TU) = trace(UD^2U^T) = trace((UDU^T)^2)) [by the property of matrix exponentiation for a diagonalizable matrix] = trace(C^2) = trace(C @ C)

# %%
# Dimensionalities should be similar before performing plasticity, upper bound on dimensionality is 8 b/c there are 8 odors each for novel/familiar (this is the rank of the cov matrix)
# Measures how many orthogonal directions in neuron space are needed to explain the set of odors (the max number of orthogonal directions is the number of neurons themselves)
# print(C_novel0)
# print(C_familiar0)

# %%
# Loop over odors and after computing R_alpha (stationary/convergence state) for each odor, perform weight update on W_rec
# Compute increment for W_rec(i,j) which is only dependent on R_alpha(i) and R_alpha(j) (two different neurons in W_rec)
# Do it only for the nonzero weights for now (because these are the only active connections between neurons)
# - Later, we could explore whether new synapses etc are created/destroyed (the changing of a weight from zero to nonzero)

# %%
# Set up MLP which takes in R_alpha(i) and R_alpha(j) and computes an output value delta_W_rec(i,j) which is the update value for W_rec(i,j)
# Single MLP for each class of weights (W_ee, W_ei, etc), and we adjust the weights of this MLP
# - Because plasticity is different between different kinds of neurons

# %%
# Start w/ small MLP - 1 hidden layer (ex. 20 units), 2 inputs, 1 output
# Each time step, we want to compute the weight update
# Compute the responses using the existing weight matrix, run thru the MLP to get the weight update, and update the weight matrix
# After n iterations, we want to calculate dimensionality (from the covariance matrix we generate from the neuron responses)
# Loss function: dim Novel / dim Familiar
# - Potential case: might make dim(Novel) as 0

# Might have to regularize the firing rate - should be close to a value we set
# Ex. could take average of neuron responses at beginning (before plasticity) and set that as target firing rate

# To prevent exploding/vanishing gradients, might have to truncate the gradient (stop it from updating after a certain iteration) because when we accumulate the gradient over the time steps to compute the response, it might blow up or just vanish
# - since the weight update is used to update the weight matrix and compute the next time step of neuron response, which in turn is fed into the MLP to compute the next weight update (very cyclical)
# Another solution - only backprop thru the last time steps of the recurrent dynamics (the time steps to compute a neuron response), b/c these are where the neuron response converges to the actual value
# Lookup how to truncate gradient PyTorch

# Instead of having plasticity act on all weights, only have plasticity between certain cell types (ex. between E and E, it will create positive feedback loop on weight update and may cause gradient blowup)
# For now, only use MLP for E -> I (minimize likelihood of gradient blowup), don't have to truncate gradient yet

# %%
import torch.nn as nn
import torch.optim as optim

def create_model() -> torch.nn.Sequential:
    # Number of neurons in hidden layer
    hidden_size = 100
    # Constrain output to certain values: nn.Hardtanh(-1, 1)
    model = nn.Sequential(
        nn.Linear(2, hidden_size),
        nn.ReLU(),
        nn.Linear(hidden_size, 1),
    )
    
    return model

# %%
# Start and stop indices for the section of W_rec we want to update, respectively 
# Takes in R_alpha, a vector of neuron responses to a particular odor
def compute_update(model: torch.nn.Sequential, R_alpha: torch.Tensor, update_inds) -> torch.Tensor:
    # Compute the same pairs of R_i and R_j for every odor
    # 1D vectors of the pre and postsynaptic neurons corresponding to the nonzero weights of W_rec
    postsyn_responses = R_alpha[update_inds[0]]
    presyn_responses = R_alpha[update_inds[1]]
    model_input = torch.vstack((presyn_responses, postsyn_responses)).t()
    slice_updates = model(model_input)
    
    updates = slice_updates.squeeze(dim=1)
    
    return updates

# %%
def odor_corrs(R):
    # We don't care about the actual responses per odor, just about a neuron's fluctuations around its mean response across odors
    R_adjusted = R - torch.mean(R, dim=1, keepdim=True)
    # Each odor becomes a variable, because we want to calculate correlations between them across neurons
    R_adjusted.t_()
    # Like cov but divides by standard deviations, effectively normalizing the values (the diagonals of the resulting matrix become 1)
    sigma_E = torch.corrcoef(R_adjusted)
    # We only care about the correlations between the familiar odors
    familiar_corrs = sigma_E[P//2:P, P//2:P] - torch.eye(P // 2)
    corr_sum = torch.sum(familiar_corrs ** 2)
    avg_corr = torch.mean(torch.abs(familiar_corrs))
    
    return corr_sum, avg_corr

# %%
# Sparsity per odor, across all (E) neurons
def sparsity_per_odor(R):
    sp_per_odor = 1 - ((torch.sum(R[:num_e], dim=0) ** 2) / (num_e * (torch.sum(R[:num_e] ** 2, dim=0))))
    return sp_per_odor

# Sparsity per (E) neuron, across a given odor family
def sparsity_per_neuron(R, odor_inds):
    sp_per_neuron = 1 - (
                (torch.sum(R[:num_e, odor_inds], dim=1) ** 2) / (P * torch.sum(R[:num_e, odor_inds] ** 2, dim=1)))
    return sp_per_neuron

# %%
# Try to minimize the correlations between values
def loss_fn(R, lambda_corr, lambda_mu, lambda_var, lambda_sp):
    corr_sum, avg_corr = odor_corrs(R)
    corr_loss = (1 / P) * corr_sum
    corr_term = lambda_corr * corr_loss
    
    means = torch.mean(R, dim=0)
    means_novel = torch.mean(means[novel_inds])
    means_familiar = torch.mean(means[familiar_inds])
    mu_term = lambda_mu * (((means_familiar - means_novel) / (means_novel + means_familiar)) ** 2)
    
    vars = torch.var(R, dim=0)
    var_novel = torch.mean(vars[novel_inds])
    var_familiar = torch.mean(vars[familiar_inds])
    var_term = lambda_var * (((var_familiar - var_novel) / (var_novel + var_familiar)) ** 2)
    
    sparsities = sparsity_per_odor(R)
    spars_novel = torch.mean(sparsities[novel_inds])
    spars_familiar = torch.mean(sparsities[familiar_inds])
    spars_term = lambda_sp * (((spars_familiar - spars_novel) / (spars_novel + spars_familiar)) ** 2)
    
    print("Avg Corr: %.4f, Corr: %.4f, Mu: %.4f, Var: %.4f, Sparsity: %.4f" % (avg_corr, corr_term, mu_term, var_term, spars_term))
    loss = corr_term + mu_term + var_term + spars_term
    return loss

# %%
# Detaching vs zero grad - should detach because we have a term dependent on the previous model iteration which isn't zero but some constant gradient, accumulated from that model output

# %%
# Upper bound for weight matrix (most weights become 10x-15x initial value if they take the naive approach of increasing inhibition)
mult = 100
w_ie = 0.5
max_weight = mult * w_ie

def loss_after_odors(model: torch.nn.Sequential, W_rec: torch.Tensor, R_current: torch.Tensor, h_bar_ff: torch.Tensor, threshold_mult, plasticity_rate, update_inds, lambda_corr, lambda_mu, lambda_var, lambda_sp, detach_grad=True, with_loss=False):
   # First, compute the respective weight updates through the novel and familiar odors from the current neural responses (which are from the current weight matrix)
    
    #updates = W_rec[update_inds].detach().clone()
    #updates.requires_grad_(True)
    updates = torch.zeros_like(W_rec[update_inds], requires_grad=True)
    W_rec.requires_grad_(True)
   
    # Shuffle which indices we look at, so we don't always gradient clip
    # for familiar odors
    for i in torch.randperm(P):
        ou = compute_update(model, R_current[:, i], update_inds)
        # Naive update rule (no weight decay)
        odor_update = plasticity_rate * ou
        # At the very end, we accumulate into W_rec so we need to check whether the new W_rec value at the very end will fit within max_weight
        with torch.no_grad():
            # Regularize by the current weight in the update, so we don't add the current weight term in this expression
            val_tensor = W_rec[update_inds] + updates + odor_update
            # E->I weights are only positive
            condition = torch.logical_and(torch.gt(val_tensor, 0.), torch.le(val_tensor, max_weight))
        
        normed_update = torch.where(condition, odor_update, 0.)
        updates = updates + normed_update
    
    W_rec = torch.index_put(W_rec, update_inds, updates, accumulate=True)
    
    R = compute_piriform_response(h_bar_ff, W_rec, threshold_mult)
    R_new = R
    
    if detach_grad:
        # We want a new R response tensor which only has the previous weight update but not anything before that
        W_rec = W_rec.detach()
        R_new = compute_piriform_response(h_bar_ff, W_rec, threshold_mult)

    
    if with_loss:
        loss = loss_fn(R, lambda_corr, lambda_mu, lambda_var, lambda_sp)
    else:
        loss = 0
    
    return loss, W_rec, R_new

# %%
# def loss_per_odor(W_rec: torch.Tensor, R_current: torch.Tensor, h_bar_ff: torch.Tensor):
#     W_rec.requires_grad_(True)
#     
#     W_rec = weight_update(W_rec, R_current, (num_e, num_neurons), (0, num_e))
#     
#     # Then find the updated neural responses from the updated weight matrix
#     R_new = compute_piriform_response(h_bar_ff, W_rec, theta)
#     
#     # Then, compute the loss, which is the ratio of the novel and familiar dimensionalities
#     loss = loss_fn(R_new)
#    
#     # We want a new R response tensor which only has the previous weight update but not anything before that
#     W_static = W_rec.detach().clone()
#     R_tosend = compute_piriform_response(h_bar_ff, W_static, theta)
#    
#     
#     return loss, W_rec, R_tosend

# %%
# This MLP changes in every loop iteration, its not biologically plausible
# We also need an outer loop to mimic multiple animals each doing this set of sniffs, then we get a more generalizable MLP which can take in two responses and compute what the ideal update would be
# A validation run would be where we freeze the weights of the MLP, give it a random initial weight matrix and h_bar feedforward input, and across loop iterations have it reduce the correlations between odors

# # Number of independent "sniffs" of the 16 odors
# num_epochs = 1000
# # Number of standard deviations from mean, 2 will make 5% of the neurons fire for a given odor
# theta = 2
# 
# model = create_model()
# # Rate at which we update W w/ delta W
# plasticity_rate = 1e-3
# #optimizer = optim.SGD(model.parameters(), lr=1e-3, momentum=0.9)
# optimizer = optim.Adam(model.parameters(), lr=1e-3)
# 
# i = correlated_mitral_activity(e=0.8)
# hbar_ff = compute_feedforward_activity(i)
# # print(f"Initial feedforward dim (novel): {compute_dim(hbar_ff, novel_inds)}")
# # print(f"Initial feedforward dim (novel): {compute_dim(hbar_ff, familiar_inds)}")
# # Initial W_rec
# W = compute_initial_recurrent_weights()
# W.requires_grad_(True)
# 
# with torch.no_grad():
#     post = (num_e, num_neurons)
#     pre = (0, num_e)
#     weights_slice = W[post[0]:post[1], pre[0]:pre[1]]
#     inds = torch.nonzero(weights_slice, as_tuple=True)
#     update_inds = (inds[0] + post[0], inds[1] + pre[0])
# 
# torch.autograd.set_detect_anomaly(True)
# # Initial neuron responses
# R = compute_piriform_response(hbar_ff, W, theta)
# with torch.no_grad():
# #     C_novel0 = compute_dim(R, novel_inds)
# #     C_familiar0 = compute_dim(R, familiar_inds)
# #     print(f"Initial responses dim (novel): {C_novel0}")
# #     print(f"Initial responses dim (familiar): {C_familiar0}")
#     print("Initial loss: \t", end="")
#     loss_fn(R)
# 
# for _ in range(num_epochs):
#     # Approach 1: update weights thru each iteration of odors then at very end compute gradient
#     optimizer.zero_grad()
#     loss, W, R = loss_after_odors(model, W, R, hbar_ff, theta, plasticity_rate, update_inds, with_loss=True)
#     loss.backward()
#     optimizer.step()

# %%
# To check theoretical minimum odor correlations, generate random gaussian matrix of shape (num_neurons, 8) and this is what the minimum correlation should be
# mu = torch.zeros((num_neurons, 16))
# std = torch.ones((num_neurons, 16))
# R_random = torch.normal(mu, std)
# loss_min = loss_fn(R_random)
# Theoretical min of 0.05

# %%
def verify_initial_activities():
    runs = 100
    avg_corrs = torch.empty((runs,))
    total_losses = torch.empty((runs,))
    for i in range(runs):
        with torch.no_grad():
            a = correlated_mitral_activity()
            h = compute_feedforward_activity(a)
            w = compute_initial_recurrent_weights()
            r = compute_piriform_response(h, w, 0)
        R_adjusted = r - torch.mean(r, dim=1, keepdim=True)
        R_adjusted.t_()
        sigma_E = torch.corrcoef(R_adjusted)
        familiar_corrs = sigma_E[P//2:P, P//2:P] - torch.eye(P // 2)
        total_loss = torch.sum(familiar_corrs ** 2)
        avg_corr = torch.mean(torch.abs(familiar_corrs))
        print(f"Loss: {total_loss.item()}, Avg Corr: {avg_corr}")
        total_losses[i] = total_loss
        avg_corrs[i] = avg_corr
    plt.hist(avg_corrs, bins=15)

# %%
# Number of independent "sniffs" of the 16 odors
n_inner = 1
# Number of different realizations of the odor sniffing process
n_outer = 1000

# Number of inner epochs between model updates (right now we perform one update after all the inner epochs), n_update <= n_inner
n_update = n_inner
# Number of inner epochs across which the gradient is tracked (right now we detach the gradient after each inner epoch), n_track <= n_inner
n_track = 1

# n_track = n_update to test formulation where we track the gradient across a subset of the inner epochs and update the model
# If n_update > n_track, the model will have multiple "gradient" paths of loss accumulated: ex. inner epochs 1-5 and a separate branch of 6-10
# If n_update < n_track, it doesn't matter b/c the model will truncate the history past its previous update since the gradient is zeroed

# Number of standard deviations from mean, we are trying 0 b/c 1 and 2 is too sparse
threshold_multiplier = 0

# How much to weight each of the regularization terms
lambda_corr, lambda_mu, lambda_var, lambda_sp = 1, 0, 0, 0

# Try lowering plasticity across iterations
start_rate = 1e-3
end_rate = 1e-5
# scale = np.log10(end_rate / start_rate)
def plasticity_ramp(i):
    # Linear ramp
    slope = (end_rate - start_rate) / n_outer
    rate = (slope * i) + start_rate
    # Exponential ramp
    #rate = start_rate * (10 ** ((scale * i) / epochs_outer))
    return rate

model = create_model()

def train_model():
    
    optimizer = optim.SGD(model.parameters(), lr=1e-3, momentum=0.9)
    #optimizer = optim.Adam(model.parameters(), lr=1e-5)
    
    post = (num_e, num_neurons)
    pre = (0, num_e)
    
    losses = torch.empty((int(n_update * n_outer,)))
    # batch every 20 (ex. tried 50 and was slightly more noisy (but w/ similar mean))
    batch_every = 20
    batch_loss = 0
    for outer_e in range(n_outer):
        i = correlated_mitral_activity()
        hbar_ff = compute_feedforward_activity(i)
        # print(f"Initial feedforward dim (novel): {compute_dim(hbar_ff, novel_inds)}")
        # print(f"Initial feedforward dim (novel): {compute_dim(hbar_ff, familiar_inds)}")
        # Initial W_rec
        
        W = compute_initial_recurrent_weights()
        W.requires_grad_(True)
        
        with torch.no_grad():
            weights_slice = W[post[0]:post[1], pre[0]:pre[1]]
            inds = torch.nonzero(weights_slice, as_tuple=True)
            update_inds = (inds[0] + post[0], inds[1] + pre[0])
        
        # Initial neuron responses
        R = compute_piriform_response(hbar_ff, W, threshold_multiplier)
        #plasticity_rate = plasticity_ramp(outer_e)
        # Plasticity rate needs to be this high to enable decorrelation (but comes w/ drawback of noise)
        plasticity_rate = 1e-0
        print(f"Outer epoch {outer_e}, Rate: {np.log10(plasticity_rate)}, Initial loss: \t", end="")
        initial_loss = loss_fn(R, lambda_corr, lambda_mu, lambda_var, lambda_sp)
        
        for i in range(1, n_inner + 1):
            with_loss = False
            detach_grad = False
            if i % n_update == 0:
                with_loss = True
                print(f"Outer epoch {outer_e}, Inner epoch {i}, Final loss: \t", end="")
            if i % n_track == 0:
                detach_grad = True
            loss, W, R = loss_after_odors(model, W, R, hbar_ff, threshold_multiplier, plasticity_rate, update_inds, lambda_corr, lambda_mu, lambda_var, lambda_sp, detach_grad=detach_grad, with_loss=with_loss)
            
            if with_loss:
                final_loss = loss   
                # Don't include loss-min term
                total_loss = final_loss / initial_loss
                print(f"Loss ratio: {total_loss}")
                batch_loss += total_loss
                losses[outer_e + (i // n_update - 1)] = total_loss
        
        if outer_e % batch_every == 0:
            batch_loss.backward()   
            optimizer.step()
            optimizer.zero_grad()
            batch_loss = 0
                
    return losses

# %%
# Now that regime works, can we optimize it w/ hyperparameters as much as possible
# Also try "batching" across outer epochs - keep gradient over multiple outer epochs
# Then add concept of inner epochs, and then eventually move on to loss regularization terms
# Generate plot of odor correlations over time, say which hyperparameters made it work (and which update rule)
# - move into separate notebook to show the stages of the code

# %%
# TODO Ashok feedback - can we try one inner epoch for each odor realization and see whether model can just blow up E->I weights

# %%
losses = train_model()
# Out:
# Outer epoch 0, Rate: 0.0, Initial loss: 	Avg Corr: 0.2769, Corr: 0.4836, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 0, Inner epoch 1, Final loss: 	Avg Corr: 0.2786, Corr: 0.4877, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0083141326904297
# Outer epoch 1, Rate: 0.0, Initial loss: 	Avg Corr: 0.3220, Corr: 0.5733, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 1, Inner epoch 1, Final loss: 	Avg Corr: 0.3258, Corr: 0.5879, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0255200862884521
# Outer epoch 2, Rate: 0.0, Initial loss: 	Avg Corr: 0.3534, Corr: 0.7514, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 2, Inner epoch 1, Final loss: 	Avg Corr: 0.3569, Corr: 0.7688, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0231281518936157
# Outer epoch 3, Rate: 0.0, Initial loss: 	Avg Corr: 0.3255, Corr: 0.6594, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 3, Inner epoch 1, Final loss: 	Avg Corr: 0.3262, Corr: 0.6676, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0124866962432861
# Outer epoch 4, Rate: 0.0, Initial loss: 	Avg Corr: 0.2810, Corr: 0.4597, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 4, Inner epoch 1, Final loss: 	Avg Corr: 0.2697, Corr: 0.4607, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0020925998687744
# Outer epoch 5, Rate: 0.0, Initial loss: 	Avg Corr: 0.3326, Corr: 0.6485, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 5, Inner epoch 1, Final loss: 	Avg Corr: 0.3446, Corr: 0.6810, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0501004457473755
# Outer epoch 6, Rate: 0.0, Initial loss: 	Avg Corr: 0.2871, Corr: 0.4872, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 6, Inner epoch 1, Final loss: 	Avg Corr: 0.2884, Corr: 0.4931, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.012019157409668
# Outer epoch 7, Rate: 0.0, Initial loss: 	Avg Corr: 0.3070, Corr: 0.5925, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 7, Inner epoch 1, Final loss: 	Avg Corr: 0.3049, Corr: 0.5839, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9853950142860413
# Outer epoch 8, Rate: 0.0, Initial loss: 	Avg Corr: 0.2586, Corr: 0.4165, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 8, Inner epoch 1, Final loss: 	Avg Corr: 0.2573, Corr: 0.4123, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9898350238800049
# Outer epoch 9, Rate: 0.0, Initial loss: 	Avg Corr: 0.3067, Corr: 0.5602, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 9, Inner epoch 1, Final loss: 	Avg Corr: 0.3034, Corr: 0.5481, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.978390634059906
# Outer epoch 10, Rate: 0.0, Initial loss: 	Avg Corr: 0.2567, Corr: 0.4516, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 10, Inner epoch 1, Final loss: 	Avg Corr: 0.2631, Corr: 0.4652, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0301531553268433
# Outer epoch 11, Rate: 0.0, Initial loss: 	Avg Corr: 0.2661, Corr: 0.4408, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 11, Inner epoch 1, Final loss: 	Avg Corr: 0.2848, Corr: 0.5069, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.1497119665145874
# Outer epoch 12, Rate: 0.0, Initial loss: 	Avg Corr: 0.2400, Corr: 0.3547, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 12, Inner epoch 1, Final loss: 	Avg Corr: 0.2379, Corr: 0.3496, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9855222702026367
# Outer epoch 13, Rate: 0.0, Initial loss: 	Avg Corr: 0.2853, Corr: 0.5071, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 13, Inner epoch 1, Final loss: 	Avg Corr: 0.2845, Corr: 0.5116, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.008804202079773
# Outer epoch 14, Rate: 0.0, Initial loss: 	Avg Corr: 0.4211, Corr: 1.0101, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 14, Inner epoch 1, Final loss: 	Avg Corr: 0.4084, Corr: 0.9655, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9558148384094238
# Outer epoch 15, Rate: 0.0, Initial loss: 	Avg Corr: 0.2594, Corr: 0.4261, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 15, Inner epoch 1, Final loss: 	Avg Corr: 0.2595, Corr: 0.4278, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0038678646087646
# Outer epoch 16, Rate: 0.0, Initial loss: 	Avg Corr: 0.2880, Corr: 0.4925, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 16, Inner epoch 1, Final loss: 	Avg Corr: 0.2819, Corr: 0.4709, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9559720754623413
# Outer epoch 17, Rate: 0.0, Initial loss: 	Avg Corr: 0.2518, Corr: 0.4076, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 17, Inner epoch 1, Final loss: 	Avg Corr: 0.2552, Corr: 0.4114, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.009148359298706
# Outer epoch 18, Rate: 0.0, Initial loss: 	Avg Corr: 0.2696, Corr: 0.4812, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 18, Inner epoch 1, Final loss: 	Avg Corr: 0.2762, Corr: 0.4978, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0346065759658813
# Outer epoch 19, Rate: 0.0, Initial loss: 	Avg Corr: 0.2900, Corr: 0.5518, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 19, Inner epoch 1, Final loss: 	Avg Corr: 0.2950, Corr: 0.5521, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0006800889968872
# Outer epoch 20, Rate: 0.0, Initial loss: 	Avg Corr: 0.2760, Corr: 0.4892, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 20, Inner epoch 1, Final loss: 	Avg Corr: 0.2740, Corr: 0.4828, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9868326783180237
# Outer epoch 21, Rate: 0.0, Initial loss: 	Avg Corr: 0.2739, Corr: 0.4753, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 21, Inner epoch 1, Final loss: 	Avg Corr: 0.2680, Corr: 0.4594, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.966453492641449
# Outer epoch 22, Rate: 0.0, Initial loss: 	Avg Corr: 0.3359, Corr: 0.6535, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 22, Inner epoch 1, Final loss: 	Avg Corr: 0.3288, Corr: 0.6238, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9545762538909912
# Outer epoch 23, Rate: 0.0, Initial loss: 	Avg Corr: 0.3547, Corr: 0.8062, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 23, Inner epoch 1, Final loss: 	Avg Corr: 0.3551, Corr: 0.8033, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9964566826820374
# Outer epoch 24, Rate: 0.0, Initial loss: 	Avg Corr: 0.3810, Corr: 0.8132, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 24, Inner epoch 1, Final loss: 	Avg Corr: 0.3745, Corr: 0.7826, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9623519778251648
# Outer epoch 25, Rate: 0.0, Initial loss: 	Avg Corr: 0.4030, Corr: 0.9013, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 25, Inner epoch 1, Final loss: 	Avg Corr: 0.3974, Corr: 0.8797, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.97608882188797
# Outer epoch 26, Rate: 0.0, Initial loss: 	Avg Corr: 0.3133, Corr: 0.5779, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 26, Inner epoch 1, Final loss: 	Avg Corr: 0.3143, Corr: 0.5827, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0083657503128052
# Outer epoch 27, Rate: 0.0, Initial loss: 	Avg Corr: 0.3093, Corr: 0.5772, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 27, Inner epoch 1, Final loss: 	Avg Corr: 0.3054, Corr: 0.5648, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9785768389701843
# Outer epoch 28, Rate: 0.0, Initial loss: 	Avg Corr: 0.2884, Corr: 0.5077, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 28, Inner epoch 1, Final loss: 	Avg Corr: 0.2863, Corr: 0.4989, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9826052784919739
# Outer epoch 29, Rate: 0.0, Initial loss: 	Avg Corr: 0.2847, Corr: 0.5097, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 29, Inner epoch 1, Final loss: 	Avg Corr: 0.2831, Corr: 0.4992, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9794183969497681
# Outer epoch 30, Rate: 0.0, Initial loss: 	Avg Corr: 0.3034, Corr: 0.6015, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 30, Inner epoch 1, Final loss: 	Avg Corr: 0.3017, Corr: 0.5928, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9855835437774658
# Outer epoch 31, Rate: 0.0, Initial loss: 	Avg Corr: 0.2645, Corr: 0.4117, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 31, Inner epoch 1, Final loss: 	Avg Corr: 0.2635, Corr: 0.4062, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9866375923156738
# Outer epoch 32, Rate: 0.0, Initial loss: 	Avg Corr: 0.2863, Corr: 0.5248, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 32, Inner epoch 1, Final loss: 	Avg Corr: 0.2821, Corr: 0.5236, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9976950287818909
# Outer epoch 33, Rate: 0.0, Initial loss: 	Avg Corr: 0.2732, Corr: 0.4339, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 33, Inner epoch 1, Final loss: 	Avg Corr: 0.2751, Corr: 0.4359, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0046236515045166
# Outer epoch 34, Rate: 0.0, Initial loss: 	Avg Corr: 0.3183, Corr: 0.6494, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 34, Inner epoch 1, Final loss: 	Avg Corr: 0.3216, Corr: 0.6602, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0165085792541504
# Outer epoch 35, Rate: 0.0, Initial loss: 	Avg Corr: 0.3103, Corr: 0.6232, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 35, Inner epoch 1, Final loss: 	Avg Corr: 0.3115, Corr: 0.6286, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0085817575454712
# Outer epoch 36, Rate: 0.0, Initial loss: 	Avg Corr: 0.2957, Corr: 0.5481, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 36, Inner epoch 1, Final loss: 	Avg Corr: 0.2919, Corr: 0.5304, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9675911664962769
# Outer epoch 37, Rate: 0.0, Initial loss: 	Avg Corr: 0.2868, Corr: 0.5313, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 37, Inner epoch 1, Final loss: 	Avg Corr: 0.2864, Corr: 0.5316, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.000546932220459
# Outer epoch 38, Rate: 0.0, Initial loss: 	Avg Corr: 0.3472, Corr: 0.6843, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 38, Inner epoch 1, Final loss: 	Avg Corr: 0.3451, Corr: 0.6811, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9953808188438416
# Outer epoch 39, Rate: 0.0, Initial loss: 	Avg Corr: 0.3099, Corr: 0.6233, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 39, Inner epoch 1, Final loss: 	Avg Corr: 0.3111, Corr: 0.6288, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0088021755218506
# Outer epoch 40, Rate: 0.0, Initial loss: 	Avg Corr: 0.2634, Corr: 0.4626, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 40, Inner epoch 1, Final loss: 	Avg Corr: 0.2590, Corr: 0.4439, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9595568776130676
# Outer epoch 41, Rate: 0.0, Initial loss: 	Avg Corr: 0.2240, Corr: 0.3401, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 41, Inner epoch 1, Final loss: 	Avg Corr: 0.2033, Corr: 0.3015, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8864943981170654
# Outer epoch 42, Rate: 0.0, Initial loss: 	Avg Corr: 0.3086, Corr: 0.5978, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 42, Inner epoch 1, Final loss: 	Avg Corr: 0.3083, Corr: 0.5974, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9993127584457397
# Outer epoch 43, Rate: 0.0, Initial loss: 	Avg Corr: 0.2219, Corr: 0.2979, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 43, Inner epoch 1, Final loss: 	Avg Corr: 0.2185, Corr: 0.2751, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9233986139297485
# Outer epoch 44, Rate: 0.0, Initial loss: 	Avg Corr: 0.2909, Corr: 0.5403, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 44, Inner epoch 1, Final loss: 	Avg Corr: 0.2887, Corr: 0.5331, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9865213632583618
# Outer epoch 45, Rate: 0.0, Initial loss: 	Avg Corr: 0.3623, Corr: 0.7298, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 45, Inner epoch 1, Final loss: 	Avg Corr: 0.3580, Corr: 0.7125, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9764049649238586
# Outer epoch 46, Rate: 0.0, Initial loss: 	Avg Corr: 0.3186, Corr: 0.6335, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 46, Inner epoch 1, Final loss: 	Avg Corr: 0.3102, Corr: 0.5988, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9453198313713074
# Outer epoch 47, Rate: 0.0, Initial loss: 	Avg Corr: 0.2750, Corr: 0.4596, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 47, Inner epoch 1, Final loss: 	Avg Corr: 0.2704, Corr: 0.4387, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9546806216239929
# Outer epoch 48, Rate: 0.0, Initial loss: 	Avg Corr: 0.3155, Corr: 0.5952, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 48, Inner epoch 1, Final loss: 	Avg Corr: 0.3056, Corr: 0.5694, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9566448926925659
# Outer epoch 49, Rate: 0.0, Initial loss: 	Avg Corr: 0.2425, Corr: 0.4030, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 49, Inner epoch 1, Final loss: 	Avg Corr: 0.2446, Corr: 0.4176, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.036168098449707
# Outer epoch 50, Rate: 0.0, Initial loss: 	Avg Corr: 0.2525, Corr: 0.4780, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 50, Inner epoch 1, Final loss: 	Avg Corr: 0.2429, Corr: 0.4526, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9469007253646851
# Outer epoch 51, Rate: 0.0, Initial loss: 	Avg Corr: 0.2352, Corr: 0.4299, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 51, Inner epoch 1, Final loss: 	Avg Corr: 0.2324, Corr: 0.4202, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9773150086402893
# Outer epoch 52, Rate: 0.0, Initial loss: 	Avg Corr: 0.3074, Corr: 0.5302, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 52, Inner epoch 1, Final loss: 	Avg Corr: 0.2976, Corr: 0.4981, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9395337700843811
# Outer epoch 53, Rate: 0.0, Initial loss: 	Avg Corr: 0.2777, Corr: 0.5327, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 53, Inner epoch 1, Final loss: 	Avg Corr: 0.2683, Corr: 0.4930, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.925398588180542
# Outer epoch 54, Rate: 0.0, Initial loss: 	Avg Corr: 0.2181, Corr: 0.2972, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 54, Inner epoch 1, Final loss: 	Avg Corr: 0.2049, Corr: 0.2586, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8700038194656372
# Outer epoch 55, Rate: 0.0, Initial loss: 	Avg Corr: 0.3278, Corr: 0.6168, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 55, Inner epoch 1, Final loss: 	Avg Corr: 0.3287, Corr: 0.6190, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 1.0035227537155151
# Outer epoch 56, Rate: 0.0, Initial loss: 	Avg Corr: 0.2792, Corr: 0.5280, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 56, Inner epoch 1, Final loss: 	Avg Corr: 0.2744, Corr: 0.5140, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9733949303627014
# Outer epoch 57, Rate: 0.0, Initial loss: 	Avg Corr: 0.3243, Corr: 0.6135, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 57, Inner epoch 1, Final loss: 	Avg Corr: 0.3143, Corr: 0.5754, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.937900722026825
# Outer epoch 58, Rate: 0.0, Initial loss: 	Avg Corr: 0.2707, Corr: 0.4552, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 58, Inner epoch 1, Final loss: 	Avg Corr: 0.2650, Corr: 0.4381, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9624166488647461
# Outer epoch 59, Rate: 0.0, Initial loss: 	Avg Corr: 0.2834, Corr: 0.4732, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 59, Inner epoch 1, Final loss: 	Avg Corr: 0.2764, Corr: 0.4568, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9653209447860718
# Outer epoch 60, Rate: 0.0, Initial loss: 	Avg Corr: 0.3364, Corr: 0.7288, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 60, Inner epoch 1, Final loss: 	Avg Corr: 0.3280, Corr: 0.6961, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9551713466644287
# Outer epoch 61, Rate: 0.0, Initial loss: 	Avg Corr: 0.3253, Corr: 0.6335, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 61, Inner epoch 1, Final loss: 	Avg Corr: 0.3041, Corr: 0.5717, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9023752808570862
# Outer epoch 62, Rate: 0.0, Initial loss: 	Avg Corr: 0.3046, Corr: 0.5504, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 62, Inner epoch 1, Final loss: 	Avg Corr: 0.2971, Corr: 0.5229, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9500345587730408
# Outer epoch 63, Rate: 0.0, Initial loss: 	Avg Corr: 0.3034, Corr: 0.6070, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 63, Inner epoch 1, Final loss: 	Avg Corr: 0.2798, Corr: 0.5296, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8723746538162231
# Outer epoch 64, Rate: 0.0, Initial loss: 	Avg Corr: 0.2416, Corr: 0.4019, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 64, Inner epoch 1, Final loss: 	Avg Corr: 0.2227, Corr: 0.3578, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.890274703502655
# Outer epoch 65, Rate: 0.0, Initial loss: 	Avg Corr: 0.2992, Corr: 0.5537, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 65, Inner epoch 1, Final loss: 	Avg Corr: 0.2800, Corr: 0.4969, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8974054455757141
# Outer epoch 66, Rate: 0.0, Initial loss: 	Avg Corr: 0.2495, Corr: 0.4170, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 66, Inner epoch 1, Final loss: 	Avg Corr: 0.2455, Corr: 0.3990, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9569100141525269
# Outer epoch 67, Rate: 0.0, Initial loss: 	Avg Corr: 0.2962, Corr: 0.5493, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 67, Inner epoch 1, Final loss: 	Avg Corr: 0.2659, Corr: 0.4519, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8226162195205688
# Outer epoch 68, Rate: 0.0, Initial loss: 	Avg Corr: 0.3394, Corr: 0.6556, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 68, Inner epoch 1, Final loss: 	Avg Corr: 0.3168, Corr: 0.5759, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8783209323883057
# Outer epoch 69, Rate: 0.0, Initial loss: 	Avg Corr: 0.2780, Corr: 0.4887, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 69, Inner epoch 1, Final loss: 	Avg Corr: 0.2430, Corr: 0.3949, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8080432415008545
# Outer epoch 70, Rate: 0.0, Initial loss: 	Avg Corr: 0.3044, Corr: 0.5644, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 70, Inner epoch 1, Final loss: 	Avg Corr: 0.2961, Corr: 0.5308, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9403787851333618
# Outer epoch 71, Rate: 0.0, Initial loss: 	Avg Corr: 0.3088, Corr: 0.6016, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 71, Inner epoch 1, Final loss: 	Avg Corr: 0.2904, Corr: 0.5218, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8673496246337891
# Outer epoch 72, Rate: 0.0, Initial loss: 	Avg Corr: 0.2779, Corr: 0.4579, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 72, Inner epoch 1, Final loss: 	Avg Corr: 0.2553, Corr: 0.4086, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8922563791275024
# Outer epoch 73, Rate: 0.0, Initial loss: 	Avg Corr: 0.2633, Corr: 0.4413, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 73, Inner epoch 1, Final loss: 	Avg Corr: 0.2389, Corr: 0.3817, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8649398684501648
# Outer epoch 74, Rate: 0.0, Initial loss: 	Avg Corr: 0.3916, Corr: 0.9715, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 74, Inner epoch 1, Final loss: 	Avg Corr: 0.3759, Corr: 0.9115, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9381918907165527
# Outer epoch 75, Rate: 0.0, Initial loss: 	Avg Corr: 0.2579, Corr: 0.4418, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 75, Inner epoch 1, Final loss: 	Avg Corr: 0.2524, Corr: 0.4144, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.937910795211792
# Outer epoch 76, Rate: 0.0, Initial loss: 	Avg Corr: 0.3079, Corr: 0.5893, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 76, Inner epoch 1, Final loss: 	Avg Corr: 0.3017, Corr: 0.5792, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.982848048210144
# Outer epoch 77, Rate: 0.0, Initial loss: 	Avg Corr: 0.2594, Corr: 0.4405, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 77, Inner epoch 1, Final loss: 	Avg Corr: 0.2529, Corr: 0.4180, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9489347338676453
# Outer epoch 78, Rate: 0.0, Initial loss: 	Avg Corr: 0.2930, Corr: 0.5166, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 78, Inner epoch 1, Final loss: 	Avg Corr: 0.2781, Corr: 0.4709, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9116076827049255
# Outer epoch 79, Rate: 0.0, Initial loss: 	Avg Corr: 0.2911, Corr: 0.5527, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 79, Inner epoch 1, Final loss: 	Avg Corr: 0.2829, Corr: 0.5036, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9112789630889893
# Outer epoch 80, Rate: 0.0, Initial loss: 	Avg Corr: 0.2978, Corr: 0.5507, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 80, Inner epoch 1, Final loss: 	Avg Corr: 0.2691, Corr: 0.4536, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8235817551612854
# Outer epoch 81, Rate: 0.0, Initial loss: 	Avg Corr: 0.3079, Corr: 0.5881, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 81, Inner epoch 1, Final loss: 	Avg Corr: 0.2741, Corr: 0.4836, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8223481774330139
# Outer epoch 82, Rate: 0.0, Initial loss: 	Avg Corr: 0.3290, Corr: 0.6603, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 82, Inner epoch 1, Final loss: 	Avg Corr: 0.3209, Corr: 0.6159, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9327871799468994
# Outer epoch 83, Rate: 0.0, Initial loss: 	Avg Corr: 0.4069, Corr: 0.8880, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 83, Inner epoch 1, Final loss: 	Avg Corr: 0.3509, Corr: 0.6997, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7879100441932678
# Outer epoch 84, Rate: 0.0, Initial loss: 	Avg Corr: 0.2058, Corr: 0.2974, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 84, Inner epoch 1, Final loss: 	Avg Corr: 0.1998, Corr: 0.2732, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9186962246894836
# Outer epoch 85, Rate: 0.0, Initial loss: 	Avg Corr: 0.3662, Corr: 0.7551, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 85, Inner epoch 1, Final loss: 	Avg Corr: 0.3381, Corr: 0.6937, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9186996221542358
# Outer epoch 86, Rate: 0.0, Initial loss: 	Avg Corr: 0.2964, Corr: 0.5645, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 86, Inner epoch 1, Final loss: 	Avg Corr: 0.2641, Corr: 0.4730, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8378953337669373
# Outer epoch 87, Rate: 0.0, Initial loss: 	Avg Corr: 0.2579, Corr: 0.4435, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 87, Inner epoch 1, Final loss: 	Avg Corr: 0.2414, Corr: 0.3916, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8828901648521423
# Outer epoch 88, Rate: 0.0, Initial loss: 	Avg Corr: 0.2765, Corr: 0.5374, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 88, Inner epoch 1, Final loss: 	Avg Corr: 0.2449, Corr: 0.4481, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8337808847427368
# Outer epoch 89, Rate: 0.0, Initial loss: 	Avg Corr: 0.2854, Corr: 0.5271, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 89, Inner epoch 1, Final loss: 	Avg Corr: 0.2641, Corr: 0.4746, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9003872275352478
# Outer epoch 90, Rate: 0.0, Initial loss: 	Avg Corr: 0.2973, Corr: 0.4906, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 90, Inner epoch 1, Final loss: 	Avg Corr: 0.2821, Corr: 0.4411, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8991183638572693
# Outer epoch 91, Rate: 0.0, Initial loss: 	Avg Corr: 0.2523, Corr: 0.4384, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 91, Inner epoch 1, Final loss: 	Avg Corr: 0.2341, Corr: 0.3608, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8228641152381897
# Outer epoch 92, Rate: 0.0, Initial loss: 	Avg Corr: 0.2416, Corr: 0.3846, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 92, Inner epoch 1, Final loss: 	Avg Corr: 0.2120, Corr: 0.3110, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8086777329444885
# Outer epoch 93, Rate: 0.0, Initial loss: 	Avg Corr: 0.3157, Corr: 0.5959, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 93, Inner epoch 1, Final loss: 	Avg Corr: 0.2824, Corr: 0.4985, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8366042971611023
# Outer epoch 94, Rate: 0.0, Initial loss: 	Avg Corr: 0.2880, Corr: 0.5401, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 94, Inner epoch 1, Final loss: 	Avg Corr: 0.2601, Corr: 0.4499, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8330025672912598
# Outer epoch 95, Rate: 0.0, Initial loss: 	Avg Corr: 0.2542, Corr: 0.4397, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 95, Inner epoch 1, Final loss: 	Avg Corr: 0.2258, Corr: 0.3554, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8083717823028564
# Outer epoch 96, Rate: 0.0, Initial loss: 	Avg Corr: 0.3310, Corr: 0.6431, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 96, Inner epoch 1, Final loss: 	Avg Corr: 0.2854, Corr: 0.4842, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7528693079948425
# Outer epoch 97, Rate: 0.0, Initial loss: 	Avg Corr: 0.3339, Corr: 0.6578, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 97, Inner epoch 1, Final loss: 	Avg Corr: 0.2909, Corr: 0.5155, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7835597395896912
# Outer epoch 98, Rate: 0.0, Initial loss: 	Avg Corr: 0.4099, Corr: 0.9294, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 98, Inner epoch 1, Final loss: 	Avg Corr: 0.3588, Corr: 0.7247, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7798157334327698
# Outer epoch 99, Rate: 0.0, Initial loss: 	Avg Corr: 0.3163, Corr: 0.6206, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 99, Inner epoch 1, Final loss: 	Avg Corr: 0.2882, Corr: 0.5338, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8601291179656982
# Outer epoch 100, Rate: 0.0, Initial loss: 	Avg Corr: 0.2713, Corr: 0.4920, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 100, Inner epoch 1, Final loss: 	Avg Corr: 0.2513, Corr: 0.4048, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8228748440742493
# Outer epoch 101, Rate: 0.0, Initial loss: 	Avg Corr: 0.2856, Corr: 0.5275, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 101, Inner epoch 1, Final loss: 	Avg Corr: 0.2565, Corr: 0.4364, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8274312615394592
# Outer epoch 102, Rate: 0.0, Initial loss: 	Avg Corr: 0.3166, Corr: 0.6710, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 102, Inner epoch 1, Final loss: 	Avg Corr: 0.2959, Corr: 0.5740, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8555388450622559
# Outer epoch 103, Rate: 0.0, Initial loss: 	Avg Corr: 0.2817, Corr: 0.5127, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 103, Inner epoch 1, Final loss: 	Avg Corr: 0.2620, Corr: 0.4346, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8476979732513428
# Outer epoch 104, Rate: 0.0, Initial loss: 	Avg Corr: 0.2595, Corr: 0.4609, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 104, Inner epoch 1, Final loss: 	Avg Corr: 0.2427, Corr: 0.3931, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8529526591300964
# Outer epoch 105, Rate: 0.0, Initial loss: 	Avg Corr: 0.2475, Corr: 0.4163, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 105, Inner epoch 1, Final loss: 	Avg Corr: 0.2380, Corr: 0.3910, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9391792416572571
# Outer epoch 106, Rate: 0.0, Initial loss: 	Avg Corr: 0.3016, Corr: 0.5516, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 106, Inner epoch 1, Final loss: 	Avg Corr: 0.2680, Corr: 0.4472, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8106176853179932
# Outer epoch 107, Rate: 0.0, Initial loss: 	Avg Corr: 0.3271, Corr: 0.6753, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 107, Inner epoch 1, Final loss: 	Avg Corr: 0.2943, Corr: 0.5494, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8135464191436768
# Outer epoch 108, Rate: 0.0, Initial loss: 	Avg Corr: 0.3166, Corr: 0.5879, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 108, Inner epoch 1, Final loss: 	Avg Corr: 0.2633, Corr: 0.4145, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7051666378974915
# Outer epoch 109, Rate: 0.0, Initial loss: 	Avg Corr: 0.3256, Corr: 0.6930, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 109, Inner epoch 1, Final loss: 	Avg Corr: 0.3141, Corr: 0.6417, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9260504245758057
# Outer epoch 110, Rate: 0.0, Initial loss: 	Avg Corr: 0.2287, Corr: 0.3386, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 110, Inner epoch 1, Final loss: 	Avg Corr: 0.1947, Corr: 0.2619, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7734796404838562
# Outer epoch 111, Rate: 0.0, Initial loss: 	Avg Corr: 0.2887, Corr: 0.4771, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 111, Inner epoch 1, Final loss: 	Avg Corr: 0.2383, Corr: 0.3699, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7752885818481445
# Outer epoch 112, Rate: 0.0, Initial loss: 	Avg Corr: 0.3125, Corr: 0.6053, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 112, Inner epoch 1, Final loss: 	Avg Corr: 0.2949, Corr: 0.5220, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.862438440322876
# Outer epoch 113, Rate: 0.0, Initial loss: 	Avg Corr: 0.2902, Corr: 0.4847, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 113, Inner epoch 1, Final loss: 	Avg Corr: 0.2868, Corr: 0.4840, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9985763430595398
# Outer epoch 114, Rate: 0.0, Initial loss: 	Avg Corr: 0.2936, Corr: 0.4917, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 114, Inner epoch 1, Final loss: 	Avg Corr: 0.2652, Corr: 0.4214, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8570220470428467
# Outer epoch 115, Rate: 0.0, Initial loss: 	Avg Corr: 0.2415, Corr: 0.3996, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 115, Inner epoch 1, Final loss: 	Avg Corr: 0.2171, Corr: 0.3087, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.77259761095047
# Outer epoch 116, Rate: 0.0, Initial loss: 	Avg Corr: 0.3349, Corr: 0.7201, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 116, Inner epoch 1, Final loss: 	Avg Corr: 0.3218, Corr: 0.6209, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8622304201126099
# Outer epoch 117, Rate: 0.0, Initial loss: 	Avg Corr: 0.3408, Corr: 0.7145, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 117, Inner epoch 1, Final loss: 	Avg Corr: 0.2938, Corr: 0.5444, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7620387077331543
# Outer epoch 118, Rate: 0.0, Initial loss: 	Avg Corr: 0.3051, Corr: 0.5563, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 118, Inner epoch 1, Final loss: 	Avg Corr: 0.2738, Corr: 0.4695, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8440403938293457
# Outer epoch 119, Rate: 0.0, Initial loss: 	Avg Corr: 0.2762, Corr: 0.4939, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 119, Inner epoch 1, Final loss: 	Avg Corr: 0.2353, Corr: 0.3830, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7754343152046204
# Outer epoch 120, Rate: 0.0, Initial loss: 	Avg Corr: 0.2721, Corr: 0.4448, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 120, Inner epoch 1, Final loss: 	Avg Corr: 0.2324, Corr: 0.3446, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7747370600700378
# Outer epoch 121, Rate: 0.0, Initial loss: 	Avg Corr: 0.3405, Corr: 0.6654, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 121, Inner epoch 1, Final loss: 	Avg Corr: 0.3021, Corr: 0.5352, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8043201565742493
# Outer epoch 122, Rate: 0.0, Initial loss: 	Avg Corr: 0.2572, Corr: 0.4432, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 122, Inner epoch 1, Final loss: 	Avg Corr: 0.1996, Corr: 0.2860, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.6454182863235474
# Outer epoch 123, Rate: 0.0, Initial loss: 	Avg Corr: 0.3017, Corr: 0.5547, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 123, Inner epoch 1, Final loss: 	Avg Corr: 0.2663, Corr: 0.4402, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7935822606086731
# Outer epoch 124, Rate: 0.0, Initial loss: 	Avg Corr: 0.3835, Corr: 0.8057, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 124, Inner epoch 1, Final loss: 	Avg Corr: 0.3334, Corr: 0.6684, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8295716643333435
# Outer epoch 125, Rate: 0.0, Initial loss: 	Avg Corr: 0.3125, Corr: 0.5715, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 125, Inner epoch 1, Final loss: 	Avg Corr: 0.2999, Corr: 0.5369, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9393911361694336
# Outer epoch 126, Rate: 0.0, Initial loss: 	Avg Corr: 0.2604, Corr: 0.4526, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 126, Inner epoch 1, Final loss: 	Avg Corr: 0.2298, Corr: 0.3678, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8125638961791992
# Outer epoch 127, Rate: 0.0, Initial loss: 	Avg Corr: 0.2865, Corr: 0.5283, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 127, Inner epoch 1, Final loss: 	Avg Corr: 0.2529, Corr: 0.3724, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7048851251602173
# Outer epoch 128, Rate: 0.0, Initial loss: 	Avg Corr: 0.2914, Corr: 0.4832, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 128, Inner epoch 1, Final loss: 	Avg Corr: 0.2528, Corr: 0.3821, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7907946705818176
# Outer epoch 129, Rate: 0.0, Initial loss: 	Avg Corr: 0.3364, Corr: 0.6870, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 129, Inner epoch 1, Final loss: 	Avg Corr: 0.2995, Corr: 0.5660, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8238588571548462
# Outer epoch 130, Rate: 0.0, Initial loss: 	Avg Corr: 0.2881, Corr: 0.5309, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 130, Inner epoch 1, Final loss: 	Avg Corr: 0.2193, Corr: 0.3426, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.645335853099823
# Outer epoch 131, Rate: 0.0, Initial loss: 	Avg Corr: 0.2705, Corr: 0.4380, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 131, Inner epoch 1, Final loss: 	Avg Corr: 0.2273, Corr: 0.3021, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.689798891544342
# Outer epoch 132, Rate: 0.0, Initial loss: 	Avg Corr: 0.2646, Corr: 0.4643, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 132, Inner epoch 1, Final loss: 	Avg Corr: 0.2333, Corr: 0.3700, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.796906590461731
# Outer epoch 133, Rate: 0.0, Initial loss: 	Avg Corr: 0.2748, Corr: 0.4613, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 133, Inner epoch 1, Final loss: 	Avg Corr: 0.2467, Corr: 0.3780, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8194795846939087
# Outer epoch 134, Rate: 0.0, Initial loss: 	Avg Corr: 0.2488, Corr: 0.3795, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 134, Inner epoch 1, Final loss: 	Avg Corr: 0.2120, Corr: 0.2951, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7777262926101685
# Outer epoch 135, Rate: 0.0, Initial loss: 	Avg Corr: 0.3809, Corr: 0.8572, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 135, Inner epoch 1, Final loss: 	Avg Corr: 0.3052, Corr: 0.5893, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.6874074339866638
# Outer epoch 136, Rate: 0.0, Initial loss: 	Avg Corr: 0.2824, Corr: 0.4574, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 136, Inner epoch 1, Final loss: 	Avg Corr: 0.2273, Corr: 0.3120, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.6821810603141785
# Outer epoch 137, Rate: 0.0, Initial loss: 	Avg Corr: 0.2394, Corr: 0.3794, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 137, Inner epoch 1, Final loss: 	Avg Corr: 0.2216, Corr: 0.3113, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8205456137657166
# Outer epoch 138, Rate: 0.0, Initial loss: 	Avg Corr: 0.3118, Corr: 0.5703, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 138, Inner epoch 1, Final loss: 	Avg Corr: 0.2833, Corr: 0.5060, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8872116208076477
# Outer epoch 139, Rate: 0.0, Initial loss: 	Avg Corr: 0.3056, Corr: 0.5579, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 139, Inner epoch 1, Final loss: 	Avg Corr: 0.2705, Corr: 0.4503, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8071119785308838
# Outer epoch 140, Rate: 0.0, Initial loss: 	Avg Corr: 0.3362, Corr: 0.6900, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 140, Inner epoch 1, Final loss: 	Avg Corr: 0.2857, Corr: 0.5214, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7556412816047668
# Outer epoch 141, Rate: 0.0, Initial loss: 	Avg Corr: 0.2453, Corr: 0.4475, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 141, Inner epoch 1, Final loss: 	Avg Corr: 0.2058, Corr: 0.3367, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.752449095249176
# Outer epoch 142, Rate: 0.0, Initial loss: 	Avg Corr: 0.3120, Corr: 0.6189, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 142, Inner epoch 1, Final loss: 	Avg Corr: 0.2648, Corr: 0.4464, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7212775349617004
# Outer epoch 143, Rate: 0.0, Initial loss: 	Avg Corr: 0.3162, Corr: 0.5999, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 143, Inner epoch 1, Final loss: 	Avg Corr: 0.2712, Corr: 0.4801, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8002777695655823
# Outer epoch 144, Rate: 0.0, Initial loss: 	Avg Corr: 0.2521, Corr: 0.3955, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 144, Inner epoch 1, Final loss: 	Avg Corr: 0.2095, Corr: 0.2945, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.744678795337677
# Outer epoch 145, Rate: 0.0, Initial loss: 	Avg Corr: 0.2836, Corr: 0.4946, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 145, Inner epoch 1, Final loss: 	Avg Corr: 0.1965, Corr: 0.3159, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.6387456655502319
# Outer epoch 146, Rate: 0.0, Initial loss: 	Avg Corr: 0.3352, Corr: 0.6409, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 146, Inner epoch 1, Final loss: 	Avg Corr: 0.2859, Corr: 0.4814, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7512040734291077
# Outer epoch 147, Rate: 0.0, Initial loss: 	Avg Corr: 0.3175, Corr: 0.5802, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 147, Inner epoch 1, Final loss: 	Avg Corr: 0.2874, Corr: 0.4957, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8542388081550598
# Outer epoch 148, Rate: 0.0, Initial loss: 	Avg Corr: 0.3250, Corr: 0.6266, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 148, Inner epoch 1, Final loss: 	Avg Corr: 0.3123, Corr: 0.5785, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9232057332992554
# Outer epoch 149, Rate: 0.0, Initial loss: 	Avg Corr: 0.2260, Corr: 0.3376, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 149, Inner epoch 1, Final loss: 	Avg Corr: 0.2084, Corr: 0.3111, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9214188456535339
# Outer epoch 150, Rate: 0.0, Initial loss: 	Avg Corr: 0.2851, Corr: 0.5291, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 150, Inner epoch 1, Final loss: 	Avg Corr: 0.2341, Corr: 0.3998, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7556589841842651
# Outer epoch 151, Rate: 0.0, Initial loss: 	Avg Corr: 0.3171, Corr: 0.5636, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 151, Inner epoch 1, Final loss: 	Avg Corr: 0.2543, Corr: 0.3948, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7004393935203552
# Outer epoch 152, Rate: 0.0, Initial loss: 	Avg Corr: 0.3410, Corr: 0.6485, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 152, Inner epoch 1, Final loss: 	Avg Corr: 0.2795, Corr: 0.4934, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7608923316001892
# Outer epoch 153, Rate: 0.0, Initial loss: 	Avg Corr: 0.2435, Corr: 0.4013, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 153, Inner epoch 1, Final loss: 	Avg Corr: 0.2056, Corr: 0.2911, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7252486348152161
# Outer epoch 154, Rate: 0.0, Initial loss: 	Avg Corr: 0.3215, Corr: 0.6559, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 154, Inner epoch 1, Final loss: 	Avg Corr: 0.2835, Corr: 0.5142, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7839277982711792
# Outer epoch 155, Rate: 0.0, Initial loss: 	Avg Corr: 0.2726, Corr: 0.4449, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 155, Inner epoch 1, Final loss: 	Avg Corr: 0.2162, Corr: 0.3118, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7008026242256165
# Outer epoch 156, Rate: 0.0, Initial loss: 	Avg Corr: 0.2862, Corr: 0.5504, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 156, Inner epoch 1, Final loss: 	Avg Corr: 0.2306, Corr: 0.3590, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.6522336006164551
# Outer epoch 157, Rate: 0.0, Initial loss: 	Avg Corr: 0.2692, Corr: 0.4797, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 157, Inner epoch 1, Final loss: 	Avg Corr: 0.2432, Corr: 0.3768, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7854352593421936
# Outer epoch 158, Rate: 0.0, Initial loss: 	Avg Corr: 0.3219, Corr: 0.6683, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 158, Inner epoch 1, Final loss: 	Avg Corr: 0.3077, Corr: 0.6092, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9116905331611633
# Outer epoch 159, Rate: 0.0, Initial loss: 	Avg Corr: 0.4298, Corr: 1.0017, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 159, Inner epoch 1, Final loss: 	Avg Corr: 0.3410, Corr: 0.6491, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.6479817032814026
# Outer epoch 160, Rate: 0.0, Initial loss: 	Avg Corr: 0.3228, Corr: 0.5727, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 160, Inner epoch 1, Final loss: 	Avg Corr: 0.2406, Corr: 0.3515, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.6137886047363281
# Outer epoch 161, Rate: 0.0, Initial loss: 	Avg Corr: 0.2941, Corr: 0.5977, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 161, Inner epoch 1, Final loss: 	Avg Corr: 0.2391, Corr: 0.3906, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.6535080075263977
# Outer epoch 162, Rate: 0.0, Initial loss: 	Avg Corr: 0.3096, Corr: 0.6128, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 162, Inner epoch 1, Final loss: 	Avg Corr: 0.2732, Corr: 0.5121, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8356599807739258
# Outer epoch 163, Rate: 0.0, Initial loss: 	Avg Corr: 0.3531, Corr: 0.7225, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 163, Inner epoch 1, Final loss: 	Avg Corr: 0.3042, Corr: 0.5659, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.783283531665802
# Outer epoch 164, Rate: 0.0, Initial loss: 	Avg Corr: 0.2397, Corr: 0.3621, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 164, Inner epoch 1, Final loss: 	Avg Corr: 0.2178, Corr: 0.2931, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8093597888946533
# Outer epoch 165, Rate: 0.0, Initial loss: 	Avg Corr: 0.3081, Corr: 0.6021, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 165, Inner epoch 1, Final loss: 	Avg Corr: 0.2681, Corr: 0.4734, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7863303422927856
# Outer epoch 166, Rate: 0.0, Initial loss: 	Avg Corr: 0.3061, Corr: 0.5447, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 166, Inner epoch 1, Final loss: 	Avg Corr: 0.2373, Corr: 0.3663, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.6725257635116577
# Outer epoch 167, Rate: 0.0, Initial loss: 	Avg Corr: 0.2735, Corr: 0.4878, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 167, Inner epoch 1, Final loss: 	Avg Corr: 0.2303, Corr: 0.3489, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7153668999671936
# Outer epoch 168, Rate: 0.0, Initial loss: 	Avg Corr: 0.2915, Corr: 0.4981, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 168, Inner epoch 1, Final loss: 	Avg Corr: 0.2416, Corr: 0.3913, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7855639457702637
# Outer epoch 169, Rate: 0.0, Initial loss: 	Avg Corr: 0.2608, Corr: 0.4945, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 169, Inner epoch 1, Final loss: 	Avg Corr: 0.2308, Corr: 0.4073, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8237346410751343
# Outer epoch 170, Rate: 0.0, Initial loss: 	Avg Corr: 0.3577, Corr: 0.7082, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 170, Inner epoch 1, Final loss: 	Avg Corr: 0.2613, Corr: 0.4440, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.6269051432609558
# Outer epoch 171, Rate: 0.0, Initial loss: 	Avg Corr: 0.3224, Corr: 0.6402, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 171, Inner epoch 1, Final loss: 	Avg Corr: 0.2787, Corr: 0.5062, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7906925678253174
# Outer epoch 172, Rate: 0.0, Initial loss: 	Avg Corr: 0.3845, Corr: 0.8083, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 172, Inner epoch 1, Final loss: 	Avg Corr: 0.3487, Corr: 0.6671, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8253811001777649
# Outer epoch 173, Rate: 0.0, Initial loss: 	Avg Corr: 0.3307, Corr: 0.6722, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 173, Inner epoch 1, Final loss: 	Avg Corr: 0.2606, Corr: 0.4221, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.627944827079773
# Outer epoch 174, Rate: 0.0, Initial loss: 	Avg Corr: 0.3026, Corr: 0.5574, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 174, Inner epoch 1, Final loss: 	Avg Corr: 0.2973, Corr: 0.5384, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.9659117460250854
# Outer epoch 175, Rate: 0.0, Initial loss: 	Avg Corr: 0.2619, Corr: 0.4303, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 175, Inner epoch 1, Final loss: 	Avg Corr: 0.2463, Corr: 0.3619, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.8411257863044739
# Outer epoch 176, Rate: 0.0, Initial loss: 	Avg Corr: 0.3054, Corr: 0.5888, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 176, Inner epoch 1, Final loss: 	Avg Corr: 0.2473, Corr: 0.3679, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.624867856502533
# Outer epoch 177, Rate: 0.0, Initial loss: 	Avg Corr: 0.2908, Corr: 0.4903, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 177, Inner epoch 1, Final loss: 	Avg Corr: 0.2195, Corr: 0.2795, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.5700517892837524
# Outer epoch 178, Rate: 0.0, Initial loss: 	Avg Corr: 0.2774, Corr: 0.4899, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 178, Inner epoch 1, Final loss: 	Avg Corr: 0.2425, Corr: 0.3761, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7675657272338867
# Outer epoch 179, Rate: 0.0, Initial loss: 	Avg Corr: 0.3178, Corr: 0.5911, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 179, Inner epoch 1, Final loss: 	Avg Corr: 0.2456, Corr: 0.4063, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.6872972249984741
# Outer epoch 180, Rate: 0.0, Initial loss: 	Avg Corr: 0.3046, Corr: 0.5855, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# ...
# Outer epoch 940, Inner epoch 1, Final loss: 	Avg Corr: 0.1929, Corr: 0.2487, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.4336392283439636
# Outer epoch 941, Rate: 0.0, Initial loss: 	Avg Corr: 0.2600, Corr: 0.4056, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 941, Inner epoch 1, Final loss: 	Avg Corr: 0.1661, Corr: 0.1578, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.3889688551425934
# Outer epoch 942, Rate: 0.0, Initial loss: 	Avg Corr: 0.3845, Corr: 0.9058, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 942, Inner epoch 1, Final loss: 	Avg Corr: 0.2201, Corr: 0.2902, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.3204212188720703
# Outer epoch 943, Rate: 0.0, Initial loss: 	Avg Corr: 0.3467, Corr: 0.7231, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 943, Inner epoch 1, Final loss: 	Avg Corr: 0.2275, Corr: 0.3114, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.4306957423686981
# Outer epoch 944, Rate: 0.0, Initial loss: 	Avg Corr: 0.3153, Corr: 0.6161, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 944, Inner epoch 1, Final loss: 	Avg Corr: 0.2096, Corr: 0.3054, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.49567994475364685
# Outer epoch 945, Rate: 0.0, Initial loss: 	Avg Corr: 0.2853, Corr: 0.5551, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 945, Inner epoch 1, Final loss: 	Avg Corr: 0.1830, Corr: 0.2292, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.41285616159439087
# Outer epoch 946, Rate: 0.0, Initial loss: 	Avg Corr: 0.2637, Corr: 0.4608, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 946, Inner epoch 1, Final loss: 	Avg Corr: 0.1517, Corr: 0.1554, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.337312787771225
# Outer epoch 947, Rate: 0.0, Initial loss: 	Avg Corr: 0.2799, Corr: 0.4631, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 947, Inner epoch 1, Final loss: 	Avg Corr: 0.1913, Corr: 0.2494, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.538485586643219
# Outer epoch 948, Rate: 0.0, Initial loss: 	Avg Corr: 0.3039, Corr: 0.5263, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 948, Inner epoch 1, Final loss: 	Avg Corr: 0.2033, Corr: 0.2350, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.4464573860168457
# Outer epoch 949, Rate: 0.0, Initial loss: 	Avg Corr: 0.2461, Corr: 0.3979, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 949, Inner epoch 1, Final loss: 	Avg Corr: 0.1938, Corr: 0.2439, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.6128547191619873
# Outer epoch 950, Rate: 0.0, Initial loss: 	Avg Corr: 0.2913, Corr: 0.5397, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 950, Inner epoch 1, Final loss: 	Avg Corr: 0.2300, Corr: 0.3152, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.584017276763916
# Outer epoch 951, Rate: 0.0, Initial loss: 	Avg Corr: 0.2495, Corr: 0.4658, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 951, Inner epoch 1, Final loss: 	Avg Corr: 0.1776, Corr: 0.2691, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.5776529908180237
# Outer epoch 952, Rate: 0.0, Initial loss: 	Avg Corr: 0.3003, Corr: 0.5400, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 952, Inner epoch 1, Final loss: 	Avg Corr: 0.1857, Corr: 0.2209, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.4091159999370575
# Outer epoch 953, Rate: 0.0, Initial loss: 	Avg Corr: 0.2828, Corr: 0.4688, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 953, Inner epoch 1, Final loss: 	Avg Corr: 0.1734, Corr: 0.1997, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.42606624960899353
# Outer epoch 954, Rate: 0.0, Initial loss: 	Avg Corr: 0.2952, Corr: 0.5998, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 954, Inner epoch 1, Final loss: 	Avg Corr: 0.1704, Corr: 0.2163, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.3605639636516571
# Outer epoch 955, Rate: 0.0, Initial loss: 	Avg Corr: 0.3147, Corr: 0.5881, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 955, Inner epoch 1, Final loss: 	Avg Corr: 0.2025, Corr: 0.2514, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.4274415075778961
# Outer epoch 956, Rate: 0.0, Initial loss: 	Avg Corr: 0.2557, Corr: 0.4090, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 956, Inner epoch 1, Final loss: 	Avg Corr: 0.1448, Corr: 0.1358, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.3320700228214264
# Outer epoch 957, Rate: 0.0, Initial loss: 	Avg Corr: 0.2556, Corr: 0.4296, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 957, Inner epoch 1, Final loss: 	Avg Corr: 0.1441, Corr: 0.1539, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.3582063317298889
# Outer epoch 958, Rate: 0.0, Initial loss: 	Avg Corr: 0.2838, Corr: 0.4747, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 958, Inner epoch 1, Final loss: 	Avg Corr: 0.1434, Corr: 0.1505, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.31701740622520447
# Outer epoch 959, Rate: 0.0, Initial loss: 	Avg Corr: 0.2301, Corr: 0.3620, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 959, Inner epoch 1, Final loss: 	Avg Corr: 0.1005, Corr: 0.0822, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.2271210104227066
# Outer epoch 960, Rate: 0.0, Initial loss: 	Avg Corr: 0.3057, Corr: 0.5834, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 960, Inner epoch 1, Final loss: 	Avg Corr: 0.1666, Corr: 0.2276, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.39002537727355957
# Outer epoch 961, Rate: 0.0, Initial loss: 	Avg Corr: 0.2654, Corr: 0.4416, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 961, Inner epoch 1, Final loss: 	Avg Corr: 0.1371, Corr: 0.1288, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.2916507124900818
# Outer epoch 962, Rate: 0.0, Initial loss: 	Avg Corr: 0.2373, Corr: 0.3688, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 962, Inner epoch 1, Final loss: 	Avg Corr: 0.1496, Corr: 0.1580, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.4283740222454071
# Outer epoch 963, Rate: 0.0, Initial loss: 	Avg Corr: 0.3117, Corr: 0.5626, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 963, Inner epoch 1, Final loss: 	Avg Corr: 0.1627, Corr: 0.1809, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.32155659794807434
# Outer epoch 964, Rate: 0.0, Initial loss: 	Avg Corr: 0.3000, Corr: 0.4979, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 964, Inner epoch 1, Final loss: 	Avg Corr: 0.2367, Corr: 0.3550, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7131202816963196
# Outer epoch 965, Rate: 0.0, Initial loss: 	Avg Corr: 0.2639, Corr: 0.4910, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 965, Inner epoch 1, Final loss: 	Avg Corr: 0.1893, Corr: 0.2848, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.5799919366836548
# Outer epoch 966, Rate: 0.0, Initial loss: 	Avg Corr: 0.2510, Corr: 0.4422, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 966, Inner epoch 1, Final loss: 	Avg Corr: 0.1853, Corr: 0.2686, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.6073264479637146
# Outer epoch 967, Rate: 0.0, Initial loss: 	Avg Corr: 0.2411, Corr: 0.3781, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 967, Inner epoch 1, Final loss: 	Avg Corr: 0.1645, Corr: 0.1757, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.4647066593170166
# Outer epoch 968, Rate: 0.0, Initial loss: 	Avg Corr: 0.3109, Corr: 0.6027, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 968, Inner epoch 1, Final loss: 	Avg Corr: 0.1952, Corr: 0.2761, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.45819735527038574
# Outer epoch 969, Rate: 0.0, Initial loss: 	Avg Corr: 0.3668, Corr: 0.7446, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 969, Inner epoch 1, Final loss: 	Avg Corr: 0.2983, Corr: 0.5198, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.6981131434440613
# Outer epoch 970, Rate: 0.0, Initial loss: 	Avg Corr: 0.2807, Corr: 0.5416, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 970, Inner epoch 1, Final loss: 	Avg Corr: 0.1683, Corr: 0.2022, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.3732643723487854
# Outer epoch 971, Rate: 0.0, Initial loss: 	Avg Corr: 0.3130, Corr: 0.5942, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 971, Inner epoch 1, Final loss: 	Avg Corr: 0.1655, Corr: 0.1875, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.31560784578323364
# Outer epoch 972, Rate: 0.0, Initial loss: 	Avg Corr: 0.3056, Corr: 0.6210, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 972, Inner epoch 1, Final loss: 	Avg Corr: 0.1929, Corr: 0.2890, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.4654161334037781
# Outer epoch 973, Rate: 0.0, Initial loss: 	Avg Corr: 0.2572, Corr: 0.4417, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 973, Inner epoch 1, Final loss: 	Avg Corr: 0.1511, Corr: 0.1719, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.3891852796077728
# Outer epoch 974, Rate: 0.0, Initial loss: 	Avg Corr: 0.3200, Corr: 0.6560, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 974, Inner epoch 1, Final loss: 	Avg Corr: 0.2536, Corr: 0.3911, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.5961740016937256
# Outer epoch 975, Rate: 0.0, Initial loss: 	Avg Corr: 0.3656, Corr: 0.7260, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 975, Inner epoch 1, Final loss: 	Avg Corr: 0.1706, Corr: 0.2195, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.3023926019668579
# Outer epoch 976, Rate: 0.0, Initial loss: 	Avg Corr: 0.2894, Corr: 0.4912, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 976, Inner epoch 1, Final loss: 	Avg Corr: 0.1730, Corr: 0.1911, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.3889988660812378
# Outer epoch 977, Rate: 0.0, Initial loss: 	Avg Corr: 0.2614, Corr: 0.4693, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 977, Inner epoch 1, Final loss: 	Avg Corr: 0.1747, Corr: 0.2228, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.4747932553291321
# Outer epoch 978, Rate: 0.0, Initial loss: 	Avg Corr: 0.3102, Corr: 0.5894, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 978, Inner epoch 1, Final loss: 	Avg Corr: 0.1934, Corr: 0.2295, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.38933634757995605
# Outer epoch 979, Rate: 0.0, Initial loss: 	Avg Corr: 0.2757, Corr: 0.4945, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 979, Inner epoch 1, Final loss: 	Avg Corr: 0.2155, Corr: 0.3067, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.6202160120010376
# Outer epoch 980, Rate: 0.0, Initial loss: 	Avg Corr: 0.2709, Corr: 0.4600, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 980, Inner epoch 1, Final loss: 	Avg Corr: 0.1724, Corr: 0.1882, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.409138560295105
# Outer epoch 981, Rate: 0.0, Initial loss: 	Avg Corr: 0.2496, Corr: 0.4075, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 981, Inner epoch 1, Final loss: 	Avg Corr: 0.1994, Corr: 0.2361, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.5793803334236145
# Outer epoch 982, Rate: 0.0, Initial loss: 	Avg Corr: 0.3342, Corr: 0.6322, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 982, Inner epoch 1, Final loss: 	Avg Corr: 0.2247, Corr: 0.3161, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.5000080466270447
# Outer epoch 983, Rate: 0.0, Initial loss: 	Avg Corr: 0.2620, Corr: 0.4237, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 983, Inner epoch 1, Final loss: 	Avg Corr: 0.1647, Corr: 0.2115, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.49924108386039734
# Outer epoch 984, Rate: 0.0, Initial loss: 	Avg Corr: 0.2755, Corr: 0.4861, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 984, Inner epoch 1, Final loss: 	Avg Corr: 0.2270, Corr: 0.3661, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.7531704306602478
# Outer epoch 985, Rate: 0.0, Initial loss: 	Avg Corr: 0.3276, Corr: 0.6774, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 985, Inner epoch 1, Final loss: 	Avg Corr: 0.2316, Corr: 0.3719, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.5490349531173706
# Outer epoch 986, Rate: 0.0, Initial loss: 	Avg Corr: 0.2833, Corr: 0.5307, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 986, Inner epoch 1, Final loss: 	Avg Corr: 0.2077, Corr: 0.2696, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.5079863667488098
# Outer epoch 987, Rate: 0.0, Initial loss: 	Avg Corr: 0.2294, Corr: 0.4071, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 987, Inner epoch 1, Final loss: 	Avg Corr: 0.1713, Corr: 0.2272, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.5580772161483765
# Outer epoch 988, Rate: 0.0, Initial loss: 	Avg Corr: 0.2814, Corr: 0.5188, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 988, Inner epoch 1, Final loss: 	Avg Corr: 0.1712, Corr: 0.2016, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.3886847198009491
# Outer epoch 989, Rate: 0.0, Initial loss: 	Avg Corr: 0.3774, Corr: 0.8410, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 989, Inner epoch 1, Final loss: 	Avg Corr: 0.2241, Corr: 0.3458, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.41121694445610046
# Outer epoch 990, Rate: 0.0, Initial loss: 	Avg Corr: 0.3474, Corr: 0.6495, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 990, Inner epoch 1, Final loss: 	Avg Corr: 0.2074, Corr: 0.2583, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.39768362045288086
# Outer epoch 991, Rate: 0.0, Initial loss: 	Avg Corr: 0.3720, Corr: 0.8020, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 991, Inner epoch 1, Final loss: 	Avg Corr: 0.2517, Corr: 0.3935, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.49058449268341064
# Outer epoch 992, Rate: 0.0, Initial loss: 	Avg Corr: 0.2568, Corr: 0.4369, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 992, Inner epoch 1, Final loss: 	Avg Corr: 0.1392, Corr: 0.1382, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.3162534534931183
# Outer epoch 993, Rate: 0.0, Initial loss: 	Avg Corr: 0.3996, Corr: 0.8735, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 993, Inner epoch 1, Final loss: 	Avg Corr: 0.2562, Corr: 0.3738, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.42787858843803406
# Outer epoch 994, Rate: 0.0, Initial loss: 	Avg Corr: 0.2782, Corr: 0.4817, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 994, Inner epoch 1, Final loss: 	Avg Corr: 0.1730, Corr: 0.2131, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.44238027930259705
# Outer epoch 995, Rate: 0.0, Initial loss: 	Avg Corr: 0.3124, Corr: 0.5883, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 995, Inner epoch 1, Final loss: 	Avg Corr: 0.2533, Corr: 0.3905, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.6637588739395142
# Outer epoch 996, Rate: 0.0, Initial loss: 	Avg Corr: 0.3184, Corr: 0.6274, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 996, Inner epoch 1, Final loss: 	Avg Corr: 0.1960, Corr: 0.2583, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.4117441475391388
# Outer epoch 997, Rate: 0.0, Initial loss: 	Avg Corr: 0.2991, Corr: 0.6350, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 997, Inner epoch 1, Final loss: 	Avg Corr: 0.1863, Corr: 0.2605, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.41021424531936646
# Outer epoch 998, Rate: 0.0, Initial loss: 	Avg Corr: 0.2879, Corr: 0.5181, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 998, Inner epoch 1, Final loss: 	Avg Corr: 0.1601, Corr: 0.1632, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.3150758743286133
# Outer epoch 999, Rate: 0.0, Initial loss: 	Avg Corr: 0.2678, Corr: 0.4507, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Outer epoch 999, Inner epoch 1, Final loss: 	Avg Corr: 0.1385, Corr: 0.1322, Mu: 0.0000, Var: 0.0000, Sparsity: 0.0000
# Loss ratio: 0.2932542860507965

# %%
with torch.no_grad():
    plt.plot(torch.arange(losses.shape[0]), losses)
    plt.xlabel("Epoch")
    plt.ylabel("Loss ratio")
    plt.title("Loss ratio per realization over time")
    plt.show()

# %%
# size = 100
# hbar_dims = torch.empty((size,))
# for i in range(size):
#     i_activity = correlated_mitral_activity(e=0.9)
#     hbar_ff = compute_feedforward_activity(i_activity)
#     avg_dim = torch.mean(torch.Tensor([compute_dim(hbar_ff, novel_inds), compute_dim(hbar_ff, familiar_inds)]))
#     hbar_dims[i] = avg_dim
    
# Very low variance in feedforward input realizations
# print(torch.mean(hbar_dims).item())
# print(torch.var(hbar_dims).item())

# %%
i = correlated_mitral_activity()
hbar_ff = compute_feedforward_activity(i)
W_random = compute_initial_recurrent_weights()
R_random = compute_piriform_response(hbar_ff, W_random, threshold_multiplier)
E_min, E_max = torch.min(R_random[:num_e, :]), torch.max(R_random[:num_e, :])
I_min, I_max = torch.min(R_random[num_e:, :]), torch.max(R_random[num_e:, :])

# %%
num_ticks = 100
E_vals = torch.linspace(E_min, E_max, num_ticks)
I_vals = torch.linspace(I_min, I_max, num_ticks)
E_coords, I_coords = torch.meshgrid(E_vals, I_vals, indexing="ij")
R_plot = torch.stack((E_coords.flatten(), I_coords.flatten()), dim=1)
with torch.no_grad():
    plasticity_vals = model(R_plot)

# %%
# Look at how weights evolve over the course of inner epoch, for a random realization
# Store a random set of 10 weights and see how the 10 weights change over the course of the iterations

# %%
with torch.no_grad():
    plt.hist(torch.flatten(R_random[:num_e]), density=True, label="E responses")
    plt.hist(torch.flatten(R_random[num_e:]), density=True, label="I responses")
    plt.legend()
    plt.show()

# %%
fig, ax = plt.subplots()
plot = plt.scatter(R_plot[:, 0], R_plot[:, 1], c=plasticity_vals.squeeze(0), cmap='rainbow')
clrbar = fig.colorbar(plot)
clrbar.set_label('Plasticity Value')
ax.set_title('E-I plasticity based on neural responses')
plt.xlabel("E responses")
plt.ylabel("I responses")
plt.show()

# %%
# Do a plot of rho_0 vs rho_final (for ex. 100 random initializations) to see whether the model can decorrelate odors
# Even though potentiation is always positive for the set of responses, since we are doing E to I, increasing the connection strength effectively increases inhibition too, so it balances out
# Not directly hebbian because that would mean there is some constant c*r_i*r_j, but when one of the responses is decreasing, the resulting potentiation doesn't decrease
# Instead, it will be an a * r_i + b * r_j term
# These terms come from the polynomial expansion of the function defined by the model

# %%
# Look at statistics of E neurons (mean firing rate across odors, variance, etc) at initialization compared to after plasticity
# Also look at sparsity - one across odors and another across neurons (sparsity is essentially 1 minus the square of the coefficient of variation)
# We care mostly about the sparsity across neurons (ex between neurons) and what it would be between odors (should be similar between the familiar odors b/c that's where we applied the plasticity) and we also know what it's like between novel odors
# We don't want a change in firing rate, because it should be same for novel and familiar odors

# %%
# Stats at initialization
i = correlated_mitral_activity()
hbar_ff = compute_feedforward_activity(i)
with torch.no_grad():
    W_random = compute_initial_recurrent_weights()
    R_random = compute_piriform_response(hbar_ff, W_random, threshold_multiplier)
mu_familiar_0 = torch.mean(R_random[:num_e, familiar_inds], dim=1)
sig_familiar_0 = torch.var(R_random[:num_e, familiar_inds], dim=1)
mu_novel_0 = torch.mean(R_random[:num_e, novel_inds], dim=1)
sig_novel_0 = torch.var(R_random[:num_e, novel_inds], dim=1)
#print(f"Initialization: \nFamiliar -  mean: {mu_familiar_0}, var: {sig_familiar_0}\nNovel -  mean: {mu_novel_0}, var: {sig_novel_0}")

# %%
# Stats after plasticity
W_plastic = W_random.detach().clone()
R_plastic = R_random.detach().clone()
post = (num_e, num_neurons)
pre = (0, num_e)
weights_slice = W_random[post[0]:post[1], pre[0]:pre[1]]
inds = torch.nonzero(weights_slice, as_tuple=True)
update_inds = (inds[0] + post[0], inds[1] + pre[0])

# Number of weights to track
num_samples = 100
W_tracked = torch.empty((2, num_samples))
with torch.no_grad():
    for i in range(2):
        _, W_plastic, R_plastic = loss_after_odors(model, W_plastic, R_plastic, hbar_ff, threshold_multiplier, 1e-0, update_inds, lambda_corr, lambda_mu, lambda_var, lambda_sp, detach_grad=True, with_loss=False)
        track_inds = torch.randint(0, len(update_inds), size=(num_samples,))
        W_tracked[i, :] = W_plastic[update_inds][track_inds].detach()
        
mu_familiar_f = torch.mean(R_plastic[:num_e, familiar_inds], dim=1)
sig_familiar_f = torch.var(R_plastic[:num_e, familiar_inds], dim=1)
mu_novel_f = torch.mean(R_plastic[:num_e, novel_inds], dim=1)
sig_novel_f = torch.var(R_plastic[:num_e, novel_inds], dim=1)
mu_novel_diff = mu_novel_f - mu_novel_0
mu_familiar_diff = mu_familiar_f - mu_familiar_0
sig_novel_diff = sig_novel_f - sig_novel_0
sig_familiar_diff = sig_familiar_f - sig_familiar_0

# %%
with torch.no_grad():
    pct_change = ((W_tracked - w_ie) / w_ie) * 100
    plt.plot(pct_change)
    plt.xlabel("Inner epochs")
    plt.ylabel("Weight percent change")

# %%
plt.hist(mu_novel_diff, bins=50, label="Novel")
plt.hist(mu_familiar_diff, bins=50, label="Familiar")
plt.title("Difference in mean responses before and after plasticity")
plt.legend()
plt.show()

# %%
weights_slice = W_random[post[0]:post[1], pre[0]:pre[1]]
inds = torch.nonzero(weights_slice, as_tuple=True)
update_inds = (inds[0] + post[0], inds[1] + pre[0])

# %%
W_change = ((W_plastic[update_inds] - W_random[update_inds]) / W_random[update_inds]) * 100
plt.hist(W_change, bins=50)
plt.title("Percent weight change from initialization")
plt.show()
# Most weight

# %%
sp_novel_0 = sparsity_per_neuron(R_random, novel_inds)
sp_novel_f = sparsity_per_neuron(R_plastic, novel_inds)
sp_familiar_0 = sparsity_per_neuron(R_random, familiar_inds)
sp_familiar_f = sparsity_per_neuron(R_plastic, familiar_inds)

# %%
with torch.no_grad():
    plt.hist(sp_novel_0, cumulative=True, bins=num_e, histtype="step", label="Novel_0")
    plt.hist(sp_familiar_0, cumulative=True, bins=num_e, histtype="step", label="Familiar_0")
    plt.hist(sp_novel_f, cumulative=True, bins=num_e, histtype="step", label="Novel_f")
    plt.hist(sp_familiar_f, cumulative=True, bins=num_e, histtype="step", label="Familiar_f")
    plt.legend()
    plt.show()

# %%
# Create scatter plot of odor correlation vs sparsity difference - odors that are highly positively correlated should have similar sparsities across neurons, and those that are highly negatively correlated should have different sparsities across neurons
# Check - increase P' all the way to 16, and with lower correlations, there should be less variability between the sparsity for each odor
# - would tell us how much the natural spread in sparsity is

# %%
# 1. Re-run model w/ lower threshold (0 stdev above mean)
# 2. Figure out percentage-wise how much the weights actually change (do a hist)
# - if it's 1-2% it's too small, we want the weights to change 10-100%, the weights could even change 10-fold
# 3. Add metrics to training function - automatically compute sparsity etc (also look at the sparsity between odors, not just the sparsity between neurons, see if it changes for novel vs familiar)
# Create bar plot for each number of odors, how many neurons respond to that number of odors (ideally, if we have a threshold of 0 stdev, most neurons should respond to ~4 odors, since on average a neuron will respond to half of the total odors, so 8 odors, and out of those, it should be equal between 4 novel and 4 familiar)
# Hypothesis right now - weights aren't changing that much, so we can add more epoch_inner steps (since the gradient isn't blowing up)
# Then, try removing plasticity ramp - keep 1e-3 (don't do epoch_inner increase and remove plasticity ramp at same time)
# Goal: understand what mechanism the meta-learning discovered that makes correlations smaller (see whether it acts on sparsity etc)
# Think of other metrics to quantify network behavior to understand change
